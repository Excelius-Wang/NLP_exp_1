# %%
"""
  @FileName：CBOW_TF.py
  @Author：Excelius
  @CreateTime：2024/10/4 11:31
  @Company: None
  @Description：
"""
import collections
import math
import os
import logging
import random

import numpy as np
import tensorflow.compat.v1 as tf
from importlib import reload
from sklearn.manifold import TSNE
import pickle

"""----------参数----------"""
colab_cwd = '/content'
if os.getcwd() == colab_cwd:
    # 处理好的文本存储在谷歌云盘
    file_path = os.path.join(os.getcwd(), "drive", "MyDrive", "data", "txt", "wiki_seg.txt")
else:
    # 本地的文件路径
    file_path = os.path.join(os.getcwd(), "data", "txt", "wiki_seg.txt")
# 每次迭代将使用 256 个样本进行参数更新
batch_size = 256
# 单词转为稠密向量的维度
embedding_size = 350
# 滑动窗口的大小
half_window_size = 4
# 只从前1w个高频词里找
valid_window = 10000

# 用来抽取的验证单词数
valid_size = 10
# 需要验证的单词
valid_has_word = ['父亲', '中国', '电脑', '手机', '书籍', '公里', '还', '部分', '年', '之后']
# valid_examples = np.array(random.sample(range(valid_window), valid_size))
# valid_examples = np.random.choice(valid_window, valid_size, replace=False)
# 负采样的噪声单词的数量
num_sampled = 5

"""----------logging配置----------"""
# 使用 logging.info 打印信息，colab 需要 reload() 函数，否则无法打印
reload(logging)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

"""----------数据处理----------"""


def read_data(filename):
    """
    从本地文件中读取数据，
    @param filename:
    @return:
    """
    logging.info("开始读取文件：" + filename)
    with open(filename, "r", encoding="utf-8", errors='ignore') as f:
        # 一次性读取所有的行，返回一个列表
        seg_content = f.readlines()
        seg_words = []
        # 将单词都存放到seg_words列表中，不去重，方便下一步建立以词频为基础的词表
        for i in range(len(seg_content)):
            # 每 5000 行打印一次信息
            if i % 5000 == 0:
                logging.info("当前读取到第 " + str(i) + " 行，部分数据为: " + str(seg_content[i][:50]))
            # 获取当前行词的列表，使用strip()函数过滤空格包括换行符或者制表符
            seg_words.extend(seg_content[i].strip().split(" "))
    return seg_words


all_words_list = read_data(file_path)


def build_dataset(words, size):
    """
    创建词表，包括原始词表、转换后的索引词表、单词-索引表和索引-单词表
    @param words: 原始词表
    @param size: 高频词词表长度
    @return: 索引词表、原始词表、单词-索引词表、索引-单词词表
    """
    # 初始化 count 列表，其中 UNK 代表 unknown, 即高频词表以外的词
    _count = [['UNK', -1]]
    # 统计词频，只取前 vocabulary_size 个高频词, 格式为：('词', 词频)
    _word_collection = collections.Counter(words)
    logging.info('所有词的数量为：' + str(len(_word_collection)))
    # 构建高频词表
    _count.extend(_word_collection.most_common(size - 1))
    logging.info("高频词表前 20 个数据为数据为: " + str(_count[:20]))
    # 构建字典，将词转化为索引, 词典顺序为高频词顺序, 格式为('词', 索引), 其中索引从 0 开始
    _dictionary = dict()
    for _word, _ in _count:
        _dictionary[_word] = len(_dictionary)
    # 将词转化为索引存储到_data中, 词在高频词词典的话，索引为高频词词典的索引, 如果词不在字典中, 则转化为 UNK
    # 此时 _data 就是原来词的列表的索引列表
    _data = list()
    unk_count = 0
    for _word in words:
        if _word in _dictionary:
            index = _dictionary[_word]
        else:
            index = 0
            unk_count += 1
        _data.append(index)
    _count[0][1] = unk_count
    # 构建反向字典, 可以快速从词索引转化为词即 (索引-'词')
    _reverse_dictionary = dict(zip(_dictionary.values(), _dictionary.keys()))
    return _data, _count, _dictionary, _reverse_dictionary


# 高频词词表大小
vocabulary_size = 800000
# vocabulary_size = 50000

# 构建词表
data, count, dictionary, reverse_dictionary = build_dataset(all_words_list, vocabulary_size)
logging.info('所有词的数量为：' + str(len(count)))
logging.info('含 UNK 的前 20 个高频词' + str(count[: 20]))
logging.info('含 UNK 的倒数 20 个高频词' + str(count[-20:]))
logging.info('查看索引与词的映射：')
logging_str = ''.join(
    [f"{idx} : {word}, " for idx, word in zip(data[:10], [reverse_dictionary[i] for i in data[:10]])])
logging.info(logging_str)
# 完善验证单词的索引
valid_examples = []
# 如果待验证词在此表中，那么直接获得索引，否则指定为 unknown
for word in valid_has_word:
    if dictionary.get(word, None) is not None:
        valid_examples.append(dictionary[word])
    else:
        valid_examples.append(0)

# 删除原始词表，节省内存
del all_words_list
data_index = 0


def generate_batch(_batch_size, _half_window_size):
    """
    生成训练用的 batch 数据以及标签数据，其中 batch 是 上下文， label 是 目标词
    @param _batch_size: batch 的大小
    @param _half_window_size: 目标词的上下文窗口大小（只有一半）
    @return: 生成的 batch 数据 和 label 数据
    """
    global data_index
    # 初始化二维数组, 行数为 _batch_size，列数为 2 * half_window_size, 数据类型为 int32
    _batch = np.ndarray(shape=(_batch_size, 2 * _half_window_size), dtype=np.int32)
    _labels = np.ndarray(shape=(_batch_size, 1), dtype=np.int32)
    len_data = len(data)
    # 生成每个样本
    for i in range(_batch_size):
        # 当前样本的索引
        index = data_index
        # 目标词作为标签
        _labels[i] = data[(index + _half_window_size) % len_data]
        # 获取上下文词
        for k in range(2 * _half_window_size + 1):
            # 当 k 不是忽略词
            if k != _half_window_size:
                # 调整索引以适应数组存储
                t = (k if k < _half_window_size else k - 1)
                _batch[i, t] = data[(index + k) % len_data]
        # 更新数据索引
        data_index = (data_index + 1) % len_data
    return _batch, _labels


"""----------训练 & 验证----------"""
# 创建默认的 graph
graph = tf.Graph()
with graph.as_default():
    '''-----输入-----'''
    # 创建一个 TensorFlow 占位符的，类型为 32 位整数，大小为 batch_size 的一维张量
    train_dataset = tf.placeholder(tf.int32, shape=(batch_size, 2 * half_window_size))
    # 创建一个 TensorFlow 占位符的，类型为 32 位整数，大小为 batch_size x 1 的二维张量
    train_labels = tf.placeholder(tf.int32, shape=(batch_size, 1))
    # 创建常量张量, 值为 valid_examples 列表中的元素, 制定了数据类型, 用于后续作为固定输入
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    '''-----变量-----'''
    # 词嵌入矩阵, 形状为 [vocabulary_size, embedding_size], 通过训练，嵌入矩阵会学习到每个词的分布式表示（即词向量）
    # tf.random.uniform() 用于从均匀分布中随机初始化嵌入向量，范围是 [-1.0, 1.0]。给每个词的嵌入向量的初始值是在 -1 到 1 之间的随机数。
    embeddings = tf.Variable(tf.random.uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    # softmax 层的权重矩阵，形状为 [vocabulary_size, embedding_size], 用于在通过模型训练时，将词嵌入向量映射到词汇表中每个词的概率分布
    # tf.random.truncated_normal() 用于从截断的正态分布中随机初始化权重。
    # 标准差 stddev=1.0 / math.sqrt(embedding_size) 是一种常见的初始化方式，它有助于在训练开始时使网络中的权重分布更加合理，避免梯度消失或梯度爆炸问题。
    softmax_weights = tf.Variable(
        tf.random.truncated_normal([vocabulary_size, embedding_size],
                                   stddev=1.0 / math.sqrt(embedding_size)))
    # softmax_biases 是 softmax 层的偏置项，形状为 [vocabulary_size]，表示每个词汇都有一个对应的偏置
    # tf.zeros([vocabulary_size]) 使用全零初始化偏置项。这是常见的初始化方式，偏置值会在训练过程中更新
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    '''-----模型-----'''
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # 将嵌入矩阵每行元素求和得到一个向量, 与skip-gram不同, cbow的输入是上下文向量的均值, 因此需要做相应变换
    context_embeddings = []
    for i in range(2 * half_window_size):
        # 获取每个词的嵌入向量加入到数组中, train_dataset[:, i]指提取第i列的数据
        context_embeddings.append(tf.nn.embedding_lookup(embeddings, train_dataset[:, i]))
    # tf.stack() 函数将多个张量按照给定的维度堆叠起来，这里将上下文词向量堆叠成一个新的张量, 这里指的是沿着0维进行堆叠
    # tf.reduce_mean() 计算沿着第 axis: 0维（即行）对堆叠后的张量进行平均。 keep_dims=False  表示在结果中不保留被平均的维度
    avg_embed = tf.reduce_mean(tf.stack(axis=0, values=context_embeddings), 0, keep_dims=False)
    # 计算 softmax 损失，每次使用负标签样本, 使用sampled_softmax_loss()来简化计算
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(
            weights=softmax_weights, biases=softmax_biases, labels=train_labels, inputs=avg_embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size
        )
    )
    '''-----Optimizer-----'''
    # 使用 AdaGradOptimizer 进行优化，学习率会自动调整，因此初始学习率设置为 1 即可
    # minimize()这个方法用于定义要最小化的目标函数。在这里, loss 是之前计算得到的损失值
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # 计算验证集的相似度
    valid_embed = tf.nn.embedding_lookup(embeddings, valid_dataset)
    # 计算小批量示例和所有嵌入向量之间的相似性, 使用余弦距离:
    similarity = tf.matmul(valid_embed, tf.transpose(softmax_weights)) + softmax_biases
    # 计算嵌入向量 embeddings 的 L2 范数 norm
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    # 再将 embeddings 除以 L2 范数，得到标准化后的 normalized_embeddings
    normalized_embeddings = embeddings / norm
    # 计算 softmax_weights 的 L2 范数 norm
    norm_ = tf.sqrt(tf.reduce_sum(tf.square(softmax_weights), 1, keep_dims=True))
    # 再将 softmax_weights 除以 L2 范数，得到标准化后的 normalized_softmax_weights
    normalized_softmax_weights = softmax_weights / norm_
    # 计算 (normalized_softmax_weights + normalized_embeddings)^2 的 L2 范数 norm
    norm_ = tf.sqrt(tf.reduce_sum(tf.square(normalized_softmax_weights + normalized_embeddings), 1, keep_dims=True))
    # 计算 normalized_softmax_weights 和 normalized_embeddings 的平均值, 并将结果除以 norm_ 得到 normalized_embeddings_2
    normalized_embeddings_2 = (normalized_softmax_weights + normalized_embeddings) / 2.0 / norm_

num_steps = 200001

with tf.Session(graph=graph) as session:
    if int(tf.version.VERSION.split('.')[1]) > 11:
        tf.compat.v1.global_variables_initializer().run()
    else:
        tf.initialize_all_variables().run()
    logging.info("初始化完成...")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            _batch_size=batch_size,
            _half_window_size=half_window_size
        )

        feed_dict = {train_dataset: batch_inputs, train_labels: batch_labels}
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val
        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            logging.info("在第 %d 次循环的平均损失为: %f" % (step, average_loss))
            average_loss = 0

        if step % 10000 == 0:
            logging.info("验证单词与最相似的 10 个单词：")
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 10  # 取最相似的 10 个单词
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "单词 %s 的最相似的 10 个单词为：" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                logging.info(log_str)
    final_embeddings = normalized_embeddings.eval()
    final_embeddings_2 = normalized_embeddings_2.eval()  # 更好的结果

"""----------结果----------"""
# 后续需要处理的点的数量
num_points = 10000

# 创建了 t-SNE 对象 tsne，n_components 指定降维后的维度为2，init 指定了初始化方法为 pca，n_iter 指定了最大迭代次数为 5000
tsne_2 = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
# 对 final_embeddings 中的前 50000 个嵌入（从索引 1 到 50000）进行 t-SNE 降维，并将结果存储在 two_d_embeddings 中
two_d_embeddings = tsne_2.fit_transform(final_embeddings[1:num_points + 1, :])
two_d_embeddings_2 = tsne_2.fit_transform(final_embeddings_2[1:num_points + 1, :])
if os.getcwd() == colab_cwd:
    # 处理好的文本存储在谷歌云盘
    output_path = os.path.join(os.getcwd(), "drive", "MyDrive", "data", "embedding_cbow.pkl")
else:
    # 本地的文件路径
    output_path = os.path.join(os.getcwd(), "data", "embedding_cbow.pkl")
with open(output_path, 'wb') as f:
    # 使用 pickle 库将一个列表（包含 final_embeddings, final_embeddings_2, two_d_embeddings, two_d_embeddings_2 和 reverse_dictionary ）序列化并写入到文件 f 中
    pickle.dump(
        [final_embeddings[:800000, :], final_embeddings_2[:800000, :], two_d_embeddings, two_d_embeddings_2, reverse_dictionary], f)
# Out:
# 2024-10-10 06:33:58,532 : INFO : 开始读取文件：/content/drive/MyDrive/data/txt/wiki_seg.txt
# 2024-10-10 06:34:03,540 : INFO : 当前读取到第 0 行，部分数据为: 欧几里得 西元前 三 世纪 古希腊 数学家 现在 认为 几何 父 此画 拉斐尔 作品 雅典 学院 数
# 2024-10-10 06:34:03,757 : INFO : 当前读取到第 5000 行，部分数据为: 北京军区 管辖 范围 北京市 大 军区 机关 天津市 河北省 山西省 内蒙古自治区 东四 盟外 中国
# 2024-10-10 06:34:03,964 : INFO : 当前读取到第 10000 行，部分数据为: 跆拳道 跆 唐手 空手道 融合 武术 跆拳道 年 汉城 奥运 首次 列为 示范 项目 年 巴塞隆纳
# 2024-10-10 06:34:04,121 : INFO : 当前读取到第 15000 行，部分数据为: 池鹭 学名 又名 沙鹭 花洼子 交 胪 中国 池鹭 紫 邬头 红毛 鹭 沼鹭 围螺鹭 田牛奴 茭鸡
# 2024-10-10 06:34:04,269 : INFO : 当前读取到第 20000 行，部分数据为: 德国 级 装甲 舰 或称 德意志 级 装甲 舰 德国 海军 年代 符合 凡尔赛 和约 同级 舰共 三
# 2024-10-10 06:34:04,415 : INFO : 当前读取到第 25000 行，部分数据为: 父名 英语 姓名 一种 人 父名 取自 父亲 取自 母亲 名字 称作 语言 中 父名 东 斯拉夫 民
# 2024-10-10 06:34:04,548 : INFO : 当前读取到第 30000 行，部分数据为: 保罗 约 田 立克 哲学家 新 保罗 主义者 视为 美国 存在主义 代表 人物 名称 音译 中国 大
# 2024-10-10 06:34:04,685 : INFO : 当前读取到第 35000 行，部分数据为: 赵汝 伯可 两 浙东 路 天台县 人 宋朝 宗室 进士 出身 生平 绍熙 元年 将士 郎 次年 铨试
# 2024-10-10 06:36:21,573 : INFO : 单词 之后 的最相似的 10 个单词为： 轻响, 身版, 中尾拳, 谷幸穂, 稲, 兜帽, 张良任, 躬行, 乔丝特, 设及,
# 2024-10-10 06:36:29,230 : INFO : 在第 2000 次循环的平均损失为: 3.067409
# 2024-10-10 06:36:36,820 : INFO : 在第 4000 次循环的平均损失为: 2.667264
# 2024-10-10 06:36:44,410 : INFO : 在第 6000 次循环的平均损失为: 2.276278
# 2024-10-10 06:36:51,997 : INFO : 在第 8000 次循环的平均损失为: 2.084039
# 2024-10-10 06:36:59,619 : INFO : 在第 10000 次循环的平均损失为: 2.003977
# 2024-10-10 06:36:59,621 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:37:00,498 : INFO : 单词 父亲 的最相似的 10 个单词为： 部分, 父亲, UNK, 去世, 便, 时间, 说, 传统, 死, 日本,
# 2024-10-10 06:37:00,533 : INFO : 单词 中国 的最相似的 10 个单词为： 女演员, 古代, 演员, 印度, 歌手, 最早, 女性, 中华人民共和国, 重要, 文学,
# 2024-10-10 06:37:00,568 : INFO : 单词 电脑 的最相似的 10 个单词为： 使用, 电脑, 方法, 日, 版本, 自然, 年, 运动, 应用, 总统,
# 2024-10-10 06:37:00,603 : INFO : 单词 手机 的最相似的 10 个单词为： 苏联, 称为, 不, 文化, 经济, 独立, 月, 问题, 宗教, 社会,
# 2024-10-10 06:37:00,639 : INFO : 单词 书籍 的最相似的 10 个单词为： 主要, 之后, 事件, 造成, 号, 后, UNK, 皆, 日, 方法,
# 2024-10-10 06:37:00,675 : INFO : 单词 公里 的最相似的 10 个单词为： 长, 约, 全长, 达, 里程, 以上, 距离, 面积, 小时, 公路,
# 2024-10-10 06:37:00,710 : INFO : 单词 还 的最相似的 10 个单词为： 宗教, 还, 现在, 形成, 皆, 部分, 不同, 运动, 支持, 外,
# 2024-10-10 06:37:00,744 : INFO : 单词 部分 的最相似的 10 个单词为： 地区, 称为, 战争, 便, 面积, 认为, 三个, 大量, 英语, 社会,
# 2024-10-10 06:37:00,779 : INFO : 单词 年 的最相似的 10 个单词为： 出生, 毕业, 得主, 改为, 总统, 以后, 约翰, 平均, 发表, 建成,
# 2024-10-10 06:37:00,814 : INFO : 单词 之后 的最相似的 10 个单词为： 改为, 便, 一年, 进入, 战争, 印度, 发表, 才, 之后, 双方,
# 2024-10-10 06:37:08,447 : INFO : 在第 12000 次循环的平均损失为: 2.006384
# 2024-10-10 06:37:16,079 : INFO : 在第 14000 次循环的平均损失为: 1.780392
# 2024-10-10 06:37:23,666 : INFO : 在第 16000 次循环的平均损失为: 1.726284
# 2024-10-10 06:37:31,442 : INFO : 在第 18000 次循环的平均损失为: 1.863547
# 2024-10-10 06:37:39,031 : INFO : 在第 20000 次循环的平均损失为: 1.839248
# 2024-10-10 06:37:39,032 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:37:39,922 : INFO : 单词 父亲 的最相似的 10 个单词为： 去世, 父亲, 出版, 结婚, 出生, 伦敦, 岁, 死, 恢复, 离开,
# 2024-10-10 06:37:39,963 : INFO : 单词 中国 的最相似的 10 个单词为： 女演员, 亚洲, 古代, 文化, 艺术, 出版社, 作家, 经济, 制度, 电视剧,
# 2024-10-10 06:37:40,004 : INFO : 单词 电脑 的最相似的 10 个单词为： 应用, 采用, 总统, 设计, 方法, 科学, 两个, 具有, 自然, 张,
# 2024-10-10 06:37:40,044 : INFO : 单词 手机 的最相似的 10 个单词为： 问题, 亦, 苏联, 年, 导致, 语言, 说, 无法, 这是, 继续,
# 2024-10-10 06:37:40,084 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版社, 电影, 不, 发表, 事件, 时, 出版, 改革, 早期, 美国,
# 2024-10-10 06:37:40,124 : INFO : 单词 公里 的最相似的 10 个单词为： 全长, 距离, 约, 长, 最大, 公路, 小时, 英里, 处, 大约,
# 2024-10-10 06:37:40,164 : INFO : 单词 还 的最相似的 10 个单词为： 完全, 定义, 继续, 包括, 很, 数据, 组织, 毛泽东, 法律, 这种,
# 2024-10-10 06:37:40,204 : INFO : 单词 部分 的最相似的 10 个单词为： 区域, 部分, 两个, 定义, 几乎, 革命, 领导, 恢复, 分为, 基础,
# 2024-10-10 06:37:40,244 : INFO : 单词 年 的最相似的 10 个单词为： 逝世, 出版, 获, 去世, 公元前, 当选, 结婚, 举办, 约翰, 大学,
# 2024-10-10 06:37:40,284 : INFO : 单词 之后 的最相似的 10 个单词为： 结束, 占领, 恢复, 政权, 才, 结婚, 印度, 改为, 双方, 成为,
# 2024-10-10 06:37:47,799 : INFO : 在第 22000 次循环的平均损失为: 1.751803
# 2024-10-10 06:37:55,321 : INFO : 在第 24000 次循环的平均损失为: 1.732593
# 2024-10-10 06:38:02,817 : INFO : 在第 26000 次循环的平均损失为: 1.700707
# 2024-10-10 06:38:10,371 : INFO : 在第 28000 次循环的平均损失为: 1.681258
# 2024-10-10 06:38:17,855 : INFO : 在第 30000 次循环的平均损失为: 1.704761
# 2024-10-10 06:38:17,857 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:38:18,749 : INFO : 单词 父亲 的最相似的 10 个单词为： 父亲, 去世, 公主, 儿子, 国王, 返回, 生于, 杀, 一位, 出生,
# 2024-10-10 06:38:18,786 : INFO : 单词 中国 的最相似的 10 个单词为： 古代, 女演员, 内地, 近代, 中国, 南方, 专家, 中华人民共和国, 艺术, 亚洲,
# 2024-10-10 06:38:18,820 : INFO : 单词 电脑 的最相似的 10 个单词为： 设计, 制作, 应用, 使用, 方法, 采用, 计算, 一种, 系统, 数据,
# 2024-10-10 06:38:18,855 : INFO : 单词 手机 的最相似的 10 个单词为： 导致, 战争, 原因, 问题, 发现, 仍然, 上, 无法, 以前, 左右,
# 2024-10-10 06:38:18,891 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版, 事件, 认为, 创作, 香港, 小, 之后, 改革, 进入, 电影,
# 2024-10-10 06:38:18,925 : INFO : 单词 公里 的最相似的 10 个单词为： 距离, 全长, 英里, 公路, 大约, 里程, 长, 高速公路, 最大, 处,
# 2024-10-10 06:38:18,961 : INFO : 单词 还 的最相似的 10 个单词为： 包括, 外, 提供, 毛泽东, 恢复, 未, 一种, 定义, 支持, 部分,
# 2024-10-10 06:38:18,995 : INFO : 单词 部分 的最相似的 10 个单词为： 分为, 地区, 区域, 两, 比较, 结构, 两个, 变化, 恢复, 低,
# 2024-10-10 06:38:19,031 : INFO : 单词 年 的最相似的 10 个单词为： 以来, 逝世, 世界杯, 年间, 当选, 上映, 首次, 为止, 建成, 结束,
# 2024-10-10 06:38:19,067 : INFO : 单词 之后 的最相似的 10 个单词为： 恢复, 进入, 才, 再次, 结束, 先后, 不久, 返回, 击败, 再度,
# 2024-10-10 06:38:26,617 : INFO : 在第 32000 次循环的平均损失为: 1.591516
# 2024-10-10 06:38:34,294 : INFO : 在第 34000 次循环的平均损失为: 1.622814
# 2024-10-10 06:38:41,806 : INFO : 在第 36000 次循环的平均损失为: 1.581742
# 2024-10-10 06:38:49,138 : INFO : 在第 38000 次循环的平均损失为: 1.603842
# 2024-10-10 06:38:56,651 : INFO : 在第 40000 次循环的平均损失为: 1.558533
# 2024-10-10 06:38:56,653 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:38:57,540 : INFO : 单词 父亲 的最相似的 10 个单词为： 国王, 儿子, 父亲, 去世, 出生, 生平, 生于, 亨利, 二世, 兄弟,
# 2024-10-10 06:38:57,580 : INFO : 单词 中国 的最相似的 10 个单词为： 古代, 专家, 内地, 出版社, 新疆, 近代, 南方, 女演员, 分布, 中国,
# 2024-10-10 06:38:57,620 : INFO : 单词 电脑 的最相似的 10 个单词为： 采用, 应用, 开发, 处理, 产品, 版本, 技术, 推出, 数据, 功能,
# 2024-10-10 06:38:57,660 : INFO : 单词 手机 的最相似的 10 个单词为： 导致, 手机, 发现, 造成, 原因, 具有, 香港, 接受, 著, 这是,
# 2024-10-10 06:38:57,700 : INFO : 单词 书籍 的最相似的 10 个单词为： 创作, 发表, 认为, 作品, 出版社, 当时, 内容, 书籍, 先后, UNK,
# 2024-10-10 06:38:57,738 : INFO : 单词 公里 的最相似的 10 个单词为： 全长, 长, 小时, 英里, 时速, 公里, 公尺, 线路, 里程, 处,
# 2024-10-10 06:38:57,778 : INFO : 单词 还 的最相似的 10 个单词为： 未, 包括, 毛泽东, 不会, 去, 保留, 之前, 设置, 提出, 说,
# 2024-10-10 06:38:57,817 : INFO : 单词 部分 的最相似的 10 个单词为： 区域, 分为, 班次, 两, 分布, 植物, 变化, 主要, 采用, 仍,
# 2024-10-10 06:38:57,855 : INFO : 单词 年 的最相似的 10 个单词为： 左右, 以来, 年间, 世界杯, 首次, 落成, 期间, 建成, 全球, 电影,
# 2024-10-10 06:38:57,894 : INFO : 单词 之后 的最相似的 10 个单词为： 才, 战争, 多次, 逐渐, 二世, 击败, 不久, 恢复, 返回, 爆发,
# 2024-10-10 06:39:05,505 : INFO : 在第 42000 次循环的平均损失为: 1.584764
# 2024-10-10 06:39:13,140 : INFO : 在第 44000 次循环的平均损失为: 1.522777
# 2024-10-10 06:39:20,750 : INFO : 在第 46000 次循环的平均损失为: 1.518067
# 2024-10-10 06:39:28,356 : INFO : 在第 48000 次循环的平均损失为: 1.496680
# 2024-10-10 06:39:35,918 : INFO : 在第 50000 次循环的平均损失为: 1.506152
# 2024-10-10 06:39:35,920 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:39:36,797 : INFO : 单词 父亲 的最相似的 10 个单词为： 父亲, 生于, 去世, 逝世, 儿子, 国王, 祖父, 长子, 公主, 早年,
# 2024-10-10 06:39:36,833 : INFO : 单词 中国 的最相似的 10 个单词为： 古代, 专家, 新疆, 内地, 近代, 南方, 出版社, 中华人民共和国, 分布, 地理,
# 2024-10-10 06:39:36,869 : INFO : 单词 电脑 的最相似的 10 个单词为： 使用, 方法, 执行, 处理, 产品, 开发, 电子, 软体, 一种, 采用,
# 2024-10-10 06:39:36,908 : INFO : 单词 手机 的最相似的 10 个单词为： 手机, 独立, 推出, 导致, 无法, 原因, 加上, 不是, 接受, 年,
# 2024-10-10 06:39:36,948 : INFO : 单词 书籍 的最相似的 10 个单词为： 创作, 以后, 发展, 作品, 内容, 人物, 小学, 现代, 改革, 著作,
# 2024-10-10 06:39:36,989 : INFO : 单词 公里 的最相似的 10 个单词为： 公里, 距离, 英里, 时速, 里程, 距, 总长, 长约, 市区, 线路,
# 2024-10-10 06:39:37,028 : INFO : 单词 还 的最相似的 10 个单词为： 保留, 不会, 后来, 解释, 说, 提到, 外, 之外, 不是, 非,
# 2024-10-10 06:39:37,064 : INFO : 单词 部分 的最相似的 10 个单词为： 分为, 两, 部分, 小, 形成, 低, 地区, 连接, 只, 阶段,
# 2024-10-10 06:39:37,098 : INFO : 单词 年 的最相似的 10 个单词为： 出版, 以来, 逝世, 世界杯, 至今, 他于, 以前, 首次, 左右, 为止,
# 2024-10-10 06:39:37,131 : INFO : 单词 之后 的最相似的 10 个单词为： 进入, 不久, 逐渐, 便, 再, 战争, 势力, 去世, 多次, 爆发,
# 2024-10-10 06:39:44,670 : INFO : 在第 52000 次循环的平均损失为: 1.460748
# 2024-10-10 06:39:52,298 : INFO : 在第 54000 次循环的平均损失为: 1.480970
# 2024-10-10 06:39:59,806 : INFO : 在第 56000 次循环的平均损失为: 1.480608
# 2024-10-10 06:40:07,170 : INFO : 在第 58000 次循环的平均损失为: 1.434762
# 2024-10-10 06:40:14,556 : INFO : 在第 60000 次循环的平均损失为: 1.458923
# 2024-10-10 06:40:14,558 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:40:15,434 : INFO : 单词 父亲 的最相似的 10 个单词为： 去世, 国王, 生平, 逝世, 祖父, 父亲, 生于, 儿子, 长子, 妻子,
# 2024-10-10 06:40:15,474 : INFO : 单词 中国 的最相似的 10 个单词为： 近代, 中国, 新疆, 古代, 南方, 专家, 中华人民共和国, 地理, 湖北, 人民,
# 2024-10-10 06:40:15,515 : INFO : 单词 电脑 的最相似的 10 个单词为： 使用, 产品, 方法, 推出, 系统, 应用, 软体, 执行, 采用, 信息,
# 2024-10-10 06:40:15,555 : INFO : 单词 手机 的最相似的 10 个单词为： 导致, 造成, 推出, 加上, 原因, 应用, 德国, 北京, 独立, 网站,
# 2024-10-10 06:40:15,596 : INFO : 单词 书籍 的最相似的 10 个单词为： 创作, 作品, 人物, 著作, 以后, 发表, 作者, 香港, 书籍, 小学,
# 2024-10-10 06:40:15,636 : INFO : 单词 公里 的最相似的 10 个单词为： 距离, 公里, 时速, 英里, 里程, 总长, 约, 长约, 处, 长,
# 2024-10-10 06:40:15,675 : INFO : 单词 还 的最相似的 10 个单词为： 之外, 保留, 包含, 写, 未, 不会, 包括, 提到, 毛泽东, 拥有,
# 2024-10-10 06:40:15,716 : INFO : 单词 部分 的最相似的 10 个单词为： 班次, 两, 分为, 低, 地区, 阶段, 采用, 连接, 特征, 路段,
# 2024-10-10 06:40:15,755 : INFO : 单词 年 的最相似的 10 个单词为： 年间, 以来, 至今, 他于, 在位, 为止, 球季, 直到, 左右, 以前,
# 2024-10-10 06:40:15,794 : INFO : 单词 之后 的最相似的 10 个单词为： 才, 战争, 再, 失败, 一世, 政权, 逐渐, 再次, 不久, 结束,
# 2024-10-10 06:40:23,342 : INFO : 在第 62000 次循环的平均损失为: 1.448929
# 2024-10-10 06:40:30,903 : INFO : 在第 64000 次循环的平均损失为: 1.438618
# 2024-10-10 06:40:38,415 : INFO : 在第 66000 次循环的平均损失为: 1.414170
# 2024-10-10 06:40:45,965 : INFO : 在第 68000 次循环的平均损失为: 1.389404
# 2024-10-10 06:40:53,519 : INFO : 在第 70000 次循环的平均损失为: 1.391867
# 2024-10-10 06:40:53,520 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:40:54,423 : INFO : 单词 父亲 的最相似的 10 个单词为： 公主, 家庭, 祖父, 长子, 杀, 去世, 生于, 妻子, 国王, 孩子,
# 2024-10-10 06:40:54,460 : INFO : 单词 中国 的最相似的 10 个单词为： 古代, 南方, 近代, 北京, 中国, 新疆, 地理, 最早, 朝鲜, 出版社,
# 2024-10-10 06:40:54,497 : INFO : 单词 电脑 的最相似的 10 个单词为： 使用, 系统, 产品, 方法, 软体, 执行, 采用, 网路, 处理, 推出,
# 2024-10-10 06:40:54,534 : INFO : 单词 手机 的最相似的 10 个单词为： 造成, 推出, 功能, 导致, 才, 软件, 电脑, 结构, 北京, 信息,
# 2024-10-10 06:40:54,569 : INFO : 单词 书籍 的最相似的 10 个单词为： 创作, 著作, 出版社, 杂志, 人物, 相关, 文章, 漫画, 作品, 著,
# 2024-10-10 06:40:54,606 : INFO : 单词 公里 的最相似的 10 个单词为： 时速, 公里, 里程, 总长, 距, 长约, 英里, 距离, 宽, 直径,
# 2024-10-10 06:40:54,641 : INFO : 单词 还 的最相似的 10 个单词为： 之外, 包含, 提出, 没, 去, 说, 必须, 意见, 未, 著,
# 2024-10-10 06:40:54,675 : INFO : 单词 部分 的最相似的 10 个单词为： 班次, 组成, 部分, 构成, 特征, 区域, 附近, 路段, 只, 地区,
# 2024-10-10 06:40:54,709 : INFO : 单词 年 的最相似的 10 个单词为： 世界杯, 至今, 直至, 在位, 电视剧, 以后, 奥运会, 夏季, 获, 为止,
# 2024-10-10 06:40:54,743 : INFO : 单词 之后 的最相似的 10 个单词为： 继, 战争, 立即, 才, 逐渐, 二战, 回归, 进入, 返回, 失去,
# 2024-10-10 06:41:02,306 : INFO : 在第 72000 次循环的平均损失为: 1.412204
# 2024-10-10 06:41:09,893 : INFO : 在第 74000 次循环的平均损失为: 1.377870
# 2024-10-10 06:41:17,536 : INFO : 在第 76000 次循环的平均损失为: 1.410887
# 2024-10-10 06:41:25,051 : INFO : 在第 78000 次循环的平均损失为: 1.314946
# 2024-10-10 06:41:32,392 : INFO : 在第 80000 次循环的平均损失为: 1.354796
# 2024-10-10 06:41:32,393 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:41:33,271 : INFO : 单词 父亲 的最相似的 10 个单词为： 去世, 家庭, 生于, 出生, 祖父, 国王, 孩子, 妻子, 杀, 生平,
# 2024-10-10 06:41:33,309 : INFO : 单词 中国 的最相似的 10 个单词为： 古代, 南方, 旅游, 近代, 新疆, 中国, 集团, 有限公司, 产品, 贸易,
# 2024-10-10 06:41:33,344 : INFO : 单词 电脑 的最相似的 10 个单词为： 软体, 执行, 应用, 产品, 网路, 处理, 系统, 采用, 资讯, 支援,
# 2024-10-10 06:41:33,379 : INFO : 单词 手机 的最相似的 10 个单词为： 推出, 才, 电脑, 造成, 应用, 导致, 软件, 提供, 环境, 少,
# 2024-10-10 06:41:33,414 : INFO : 单词 书籍 的最相似的 10 个单词为： 创作, 杂志, 著作, 发表, 经常, 作品, 书籍, 漫画, 收录, 文章,
# 2024-10-10 06:41:33,449 : INFO : 单词 公里 的最相似的 10 个单词为： 时速, 英里, 里程, 距离, 公里, 长约, 总长, 约, 海拔, 宽,
# 2024-10-10 06:41:33,484 : INFO : 单词 还 的最相似的 10 个单词为： 外, 没, 写, 知道, 一生, 包括, 加入, 想, 用来, 包含,
# 2024-10-10 06:41:33,519 : INFO : 单词 部分 的最相似的 10 个单词为： 班次, 两, 组成, 连接, 改为, 特征, 分为, 地区, 东西, 区域,
# 2024-10-10 06:41:33,555 : INFO : 单词 年 的最相似的 10 个单词为： 以来, 出版, 夏季, 爆发, 直到, 直至, 竣工, 以后, 落成, 他于,
# 2024-10-10 06:41:33,591 : INFO : 单词 之后 的最相似的 10 个单词为： 继, 回归, 再次, 三年, 逐渐, 返回, 二战, 回, 多次, 才,
# 2024-10-10 06:41:41,141 : INFO : 在第 82000 次循环的平均损失为: 1.348734
# 2024-10-10 06:41:48,734 : INFO : 在第 84000 次循环的平均损失为: 1.335418
# 2024-10-10 06:41:56,271 : INFO : 在第 86000 次循环的平均损失为: 1.306719
# 2024-10-10 06:42:03,798 : INFO : 在第 88000 次循环的平均损失为: 1.325540
# 2024-10-10 06:42:11,360 : INFO : 在第 90000 次循环的平均损失为: 1.321305
# 2024-10-10 06:42:11,361 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:42:12,243 : INFO : 单词 父亲 的最相似的 10 个单词为： 去世, 祖父, 逝世, 父母, 出生, 生平, 家中, 父亲, 结婚, 妹妹,
# 2024-10-10 06:42:12,277 : INFO : 单词 中国 的最相似的 10 个单词为： 古代, 近代, 新疆, 内地, 中国, 南方, 地理, 中华民国, 专家, 著名,
# 2024-10-10 06:42:12,311 : INFO : 单词 电脑 的最相似的 10 个单词为： 应用, 软体, 资讯, 支援, 自然, 用户, 技术, 采用, 网路, 系统,
# 2024-10-10 06:42:12,344 : INFO : 单词 手机 的最相似的 10 个单词为： 提供, 应用, 手机, 功能, 软件, 设备, 网路, 推出, 少, 武器,
# 2024-10-10 06:42:12,378 : INFO : 单词 书籍 的最相似的 10 个单词为： 著作, 漫画, 杂志, 创作, 书籍, 人物, 发行, 文章, 阅读, 动画,
# 2024-10-10 06:42:12,414 : INFO : 单词 公里 的最相似的 10 个单词为： 全长, 英里, 距离, 里程, 长约, 时速, 总长, 海拔, 约, 距,
# 2024-10-10 06:42:12,448 : INFO : 单词 还 的最相似的 10 个单词为： 外, 没, 知道, 包含, 提出, 意见, 以外, 设有, 保护, 很多,
# 2024-10-10 06:42:12,482 : INFO : 单词 部分 的最相似的 10 个单词为： 地区, 两, 班次, 分为, 东西, 分成, 一部分, 区域, 组成, 电车,
# 2024-10-10 06:42:12,516 : INFO : 单词 年 的最相似的 10 个单词为： 直到, 他于, 后于, 在位, 至今, 大选, 为止, 落成, 爆发, 创立,
# 2024-10-10 06:42:12,550 : INFO : 单词 之后 的最相似的 10 个单词为： 继, 二战, 两年, 一年, 回归, 再, 离开, 回, 第二次世界大战, 逐渐,
# 2024-10-10 06:42:20,095 : INFO : 在第 92000 次循环的平均损失为: 1.299996
# 2024-10-10 06:42:27,636 : INFO : 在第 94000 次循环的平均损失为: 1.267219
# 2024-10-10 06:42:35,363 : INFO : 在第 96000 次循环的平均损失为: 1.315497
# 2024-10-10 06:42:43,115 : INFO : 在第 98000 次循环的平均损失为: 1.285510
# 2024-10-10 06:42:50,658 : INFO : 在第 100000 次循环的平均损失为: 1.268757
# 2024-10-10 06:42:50,659 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:42:51,543 : INFO : 单词 父亲 的最相似的 10 个单词为： 生平, 去世, 家中, 祖父, 父亲, 出生, 父母, 儿子, 家庭, 杀,
# 2024-10-10 06:42:51,579 : INFO : 单词 中国 的最相似的 10 个单词为： 内地, 古代, 地理, 南方, 新疆, 浙江, 著名, 中国, 北方, 传统,
# 2024-10-10 06:42:51,615 : INFO : 单词 电脑 的最相似的 10 个单词为： 应用, 资讯, 开发, 支援, 方式, 采用, 程序, 用户, 技术, 版本,
# 2024-10-10 06:42:51,651 : INFO : 单词 手机 的最相似的 10 个单词为： 电脑, 武器, 软件, 提供, 版本, 少, 应用, 网路, 推出, 网络,
# 2024-10-10 06:42:51,689 : INFO : 单词 书籍 的最相似的 10 个单词为： 杂志, 漫画, 书籍, 创作, 理论, 相关, 出版社, 发表, 文章, 内容,
# 2024-10-10 06:42:51,726 : INFO : 单词 公里 的最相似的 10 个单词为： 全长, 英里, 距离, 里程, 长约, 时速, 总长, 公路, 距, 海拔,
# 2024-10-10 06:42:51,762 : INFO : 单词 还 的最相似的 10 个单词为： 之外, 保护, 设有, 知道, 人生, 没, 提出, 以外, 没有, 用于,
# 2024-10-10 06:42:51,796 : INFO : 单词 部分 的最相似的 10 个单词为： 地区, 两, 部分, 分为, 分成, 以下, 全部, 区域, 特征, 电车,
# 2024-10-10 06:42:51,831 : INFO : 单词 年 的最相似的 10 个单词为： 以来, 以后, 并入, 他于, 更名, 推出, 夏季, 公元, 世界杯, 后于,
# 2024-10-10 06:42:51,866 : INFO : 单词 之后 的最相似的 10 个单词为： 继, 两年, 逐渐, 一年, 第二次世界大战, 二战, 离开, 重返, 立即, 失败,
# 2024-10-10 06:42:59,331 : INFO : 在第 102000 次循环的平均损失为: 1.269211
# 2024-10-10 06:43:06,923 : INFO : 在第 104000 次循环的平均损失为: 1.269285
# 2024-10-10 06:43:14,493 : INFO : 在第 106000 次循环的平均损失为: 1.282526
# 2024-10-10 06:43:22,050 : INFO : 在第 108000 次循环的平均损失为: 1.261882
# 2024-10-10 06:43:29,631 : INFO : 在第 110000 次循环的平均损失为: 1.257291
# 2024-10-10 06:43:29,633 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:43:30,518 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 父亲, 家中, 生平, 祖父, 父母, 出生, 家庭, 亲王, 之子,
# 2024-10-10 06:43:30,554 : INFO : 单词 中国 的最相似的 10 个单词为： 内地, 浙江, 古代, 南方, 新疆, 西藏, 专家, 中国, 产品, 北京,
# 2024-10-10 06:43:30,588 : INFO : 单词 电脑 的最相似的 10 个单词为： 装置, 网路, 应用, 设计, 技术, 开发, 通讯, 用户, 程序, 软体,
# 2024-10-10 06:43:30,622 : INFO : 单词 手机 的最相似的 10 个单词为： 电脑, 提供, 网路, 武器, 功能, 无线, 软件, 网络, 服务, 少,
# 2024-10-10 06:43:30,657 : INFO : 单词 书籍 的最相似的 10 个单词为： 杂志, 漫画, 文章, 出版社, 收录, 创作, 著作, 作家, 书籍, 阅读,
# 2024-10-10 06:43:30,694 : INFO : 单词 公里 的最相似的 10 个单词为： 英里, 距离, 公里, 里程, 时速, 长约, 总长, 距, 南北, 海拔,
# 2024-10-10 06:43:30,729 : INFO : 单词 还 的最相似的 10 个单词为： 外, 设有, 没, 很多, 未, 用于, 建造, 以外, 拥有, 保留,
# 2024-10-10 06:43:30,764 : INFO : 单词 部分 的最相似的 10 个单词为： 班次, 分成, 地区, 两, 分为, 东西, 数量, 区域, 商场, 全部,
# 2024-10-10 06:43:30,800 : INFO : 单词 年 的最相似的 10 个单词为： 为止, 并入, 公元, 世界杯, 夏季, 曾于, 后于, 以后, 建于, 以前,
# 2024-10-10 06:43:30,836 : INFO : 单词 之后 的最相似的 10 个单词为： 二战, 两年, 不再, 第二次世界大战, 不久, 离开, 逐渐, 去世, 回归, 返回,
# 2024-10-10 06:43:38,385 : INFO : 在第 112000 次循环的平均损失为: 1.259662
# 2024-10-10 06:43:45,976 : INFO : 在第 114000 次循环的平均损失为: 1.259774
# 2024-10-10 06:43:53,581 : INFO : 在第 116000 次循环的平均损失为: 1.241281
# 2024-10-10 06:44:01,240 : INFO : 在第 118000 次循环的平均损失为: 1.258570
# 2024-10-10 06:44:08,744 : INFO : 在第 120000 次循环的平均损失为: 1.243495
# 2024-10-10 06:44:08,745 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:44:09,610 : INFO : 单词 父亲 的最相似的 10 个单词为： 去世, 家中, 父母, 生平, 祖父, 出生, 家庭, 继承, 逝世, 玛丽,
# 2024-10-10 06:44:09,645 : INFO : 单词 中国 的最相似的 10 个单词为： 内地, 南方, 新疆, 古代, 浙江, 西藏, 山东, 广州, 传统, 近代,
# 2024-10-10 06:44:09,678 : INFO : 单词 电脑 的最相似的 10 个单词为： 装置, 资讯, 设备, 通讯, 软体, 网路, 电脑, 开发, 安装, 技术,
# 2024-10-10 06:44:09,713 : INFO : 单词 手机 的最相似的 10 个单词为： 武器, 网络, 网路, 软件, 设备, 无线, 平台, 提供, 少, 支援,
# 2024-10-10 06:44:09,747 : INFO : 单词 书籍 的最相似的 10 个单词为： 漫画, 杂志, 收录, 著作, 文章, 作者, 背景, 小说, 创作, 发表,
# 2024-10-10 06:44:09,781 : INFO : 单词 公里 的最相似的 10 个单词为： 距离, 英里, 时速, 里程, 长约, 总长, 距, 全长约, 南北, 海拔,
# 2024-10-10 06:44:09,815 : INFO : 单词 还 的最相似的 10 个单词为： 设有, 包含, 以外, 没, 外, 用于, 保护, 拥有, 现在, 未,
# 2024-10-10 06:44:09,852 : INFO : 单词 部分 的最相似的 10 个单词为： 班次, 两, 地区, 改为, 分为, 区域, 商场, 低, 分成, 列车,
# 2024-10-10 06:44:09,885 : INFO : 单词 年 的最相似的 10 个单词为： 后于, 以来, 世界杯, 他于, 去世, 夏天, 退役, 更名, 直到, 以后,
# 2024-10-10 06:44:09,919 : INFO : 单词 之后 的最相似的 10 个单词为： 不久, 失败, 便, 再, 返回, 加入, 一年, 去世, 过世, 两年,
# 2024-10-10 06:44:17,316 : INFO : 在第 122000 次循环的平均损失为: 1.238486
# 2024-10-10 06:44:24,861 : INFO : 在第 124000 次循环的平均损失为: 1.223100
# 2024-10-10 06:44:32,475 : INFO : 在第 126000 次循环的平均损失为: 1.242074
# 2024-10-10 06:44:40,002 : INFO : 在第 128000 次循环的平均损失为: 1.207721
# 2024-10-10 06:44:47,525 : INFO : 在第 130000 次循环的平均损失为: 1.225592
# 2024-10-10 06:44:47,526 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:44:48,413 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 家中, 去世, 父亲, 家庭, 逝世, 出生, 生于, 生平, 妹妹,
# 2024-10-10 06:44:48,448 : INFO : 单词 中国 的最相似的 10 个单词为： 内地, 古代, 南方, 新疆, 传统, 近代, 北方, 西藏, 浙江, 传入,
# 2024-10-10 06:44:48,483 : INFO : 单词 电脑 的最相似的 10 个单词为： 应用, 软体, 网路, 支援, 通讯, 版本, 电子, 资讯, 技术, 手机,
# 2024-10-10 06:44:48,517 : INFO : 单词 手机 的最相似的 10 个单词为： 软件, 武器, 提供, 网路, 平台, 应用, 机, 支援, 推出, 少,
# 2024-10-10 06:44:48,552 : INFO : 单词 书籍 的最相似的 10 个单词为： 杂志, 漫画, 著作, 出版社, 大量, 书籍, 收录, 阅读, 发表, 作者,
# 2024-10-10 06:44:48,586 : INFO : 单词 公里 的最相似的 10 个单词为： 距离, 时速, 英里, 公里, 长约, 距, 里程, 东南, 东北, 长度,
# 2024-10-10 06:44:48,621 : INFO : 单词 还 的最相似的 10 个单词为： 没, 用于, 外, 未, 留下, 设有, 拥有, 很多, 包括, 不够,
# 2024-10-10 06:44:48,654 : INFO : 单词 部分 的最相似的 10 个单词为： 班次, 区域, 地区, 三, 改为, 分为, 内容, 分成, 商场, 构成,
# 2024-10-10 06:44:48,689 : INFO : 单词 年 的最相似的 10 个单词为： 创立, 年间, 出版, 以来, 更名, 后于, 改名, 夏天, 发表, 在位,
# 2024-10-10 06:44:48,723 : INFO : 单词 之后 的最相似的 10 个单词为： 结束, 一年, 回到, 逐渐, 陆续, 失败, 第二次世界大战, 退出, 两年, 展开,
# 2024-10-10 06:44:56,265 : INFO : 在第 132000 次循环的平均损失为: 1.171107
# 2024-10-10 06:45:03,803 : INFO : 在第 134000 次循环的平均损失为: 1.196038
# 2024-10-10 06:45:11,362 : INFO : 在第 136000 次循环的平均损失为: 1.208964
# 2024-10-10 06:45:19,001 : INFO : 在第 138000 次循环的平均损失为: 1.198236
# 2024-10-10 06:45:26,610 : INFO : 在第 140000 次循环的平均损失为: 1.177602
# 2024-10-10 06:45:26,612 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:45:27,483 : INFO : 单词 父亲 的最相似的 10 个单词为： 家庭, 父亲, 母亲, 出生, 妻子, 家中, 子女, 去世, 女儿, 弟弟,
# 2024-10-10 06:45:27,518 : INFO : 单词 中国 的最相似的 10 个单词为： 内地, 传统, 近代, 古代, 南方, 西藏, 北京, 文学, 浙江, 产品,
# 2024-10-10 06:45:27,553 : INFO : 单词 电脑 的最相似的 10 个单词为： 应用, 版本, 软体, 支援, 数码, 技术, 执行, 系统, 装置, 网路,
# 2024-10-10 06:45:27,587 : INFO : 单词 手机 的最相似的 10 个单词为： 软件, 武器, 提供, 系列, 机, 网路, 无线, 应用, 电视, 支援,
# 2024-10-10 06:45:27,622 : INFO : 单词 书籍 的最相似的 10 个单词为： 书籍, 漫画, 收录, 系列, 图书馆, 优秀, 作家, 作者, 著作, 书店,
# 2024-10-10 06:45:27,656 : INFO : 单词 公里 的最相似的 10 个单词为： 时速, 英里, 距离, 长约, 距, 里程, 公里, 东南, 长度, 全长约,
# 2024-10-10 06:45:27,691 : INFO : 单词 还 的最相似的 10 个单词为： 之外, 外, 设有, 未, 拥有, 以外, 包括, 表演, 留下, 提到,
# 2024-10-10 06:45:27,726 : INFO : 单词 部分 的最相似的 10 个单词为： 班次, 分为, 分成, 内容, 延伸, 区域, 改为, 地区, 三, 商场,
# 2024-10-10 06:45:27,759 : INFO : 单词 年 的最相似的 10 个单词为： 以来, 后于, 落成, 以后, 竣工, 年间, 夏天, 在位, 至今, 出生,
# 2024-10-10 06:45:27,793 : INFO : 单词 之后 的最相似的 10 个单词为： 一年, 离开, 逐渐, 第二次世界大战, 两年, 二战, 多次, 回到, 回归, 便,
# 2024-10-10 06:45:35,182 : INFO : 在第 142000 次循环的平均损失为: 1.171677
# 2024-10-10 06:45:42,713 : INFO : 在第 144000 次循环的平均损失为: 1.146603
# 2024-10-10 06:45:50,252 : INFO : 在第 146000 次循环的平均损失为: 1.132004
# 2024-10-10 06:45:57,802 : INFO : 在第 148000 次循环的平均损失为: 1.119201
# 2024-10-10 06:46:05,380 : INFO : 在第 150000 次循环的平均损失为: 1.157385
# 2024-10-10 06:46:05,381 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:46:06,258 : INFO : 单词 父亲 的最相似的 10 个单词为： 父亲, 妻子, 生平, 母亲, 家中, 出生, 去世, 家庭, 生于, 子女,
# 2024-10-10 06:46:06,294 : INFO : 单词 中国 的最相似的 10 个单词为： 内地, 浙江, 云南, 新疆, 南方, 江苏, 古代, 中国, 上海, 文艺,
# 2024-10-10 06:46:06,330 : INFO : 单词 电脑 的最相似的 10 个单词为： 应用, 技术, 软体, 装置, 支援, 网路, 数码, 自动, 通讯, 电子,
# 2024-10-10 06:46:06,365 : INFO : 单词 手机 的最相似的 10 个单词为： 提供, 软件, 网路, 系列, 机, 无线, 支援, 行动, 应用, 功能,
# 2024-10-10 06:46:06,399 : INFO : 单词 书籍 的最相似的 10 个单词为： 书籍, 漫画, 收录, 作者, 发表, 著作, 阅读, 杂志, 一书, 图书馆,
# 2024-10-10 06:46:06,434 : INFO : 单词 公里 的最相似的 10 个单词为： 时速, 英里, 长约, 距, 公里, 距离, 东南, 长度, 里程, 小时,
# 2024-10-10 06:46:06,469 : INFO : 单词 还 的最相似的 10 个单词为： 外, 之外, 设有, 表演, 未, 拥有, 以外, 苏联, 说, 想,
# 2024-10-10 06:46:06,504 : INFO : 单词 部分 的最相似的 10 个单词为： 班次, 内容, 分为, 区域, 调整, 改为, 号线, 保留, 分成, 地区,
# 2024-10-10 06:46:06,541 : INFO : 单词 年 的最相似的 10 个单词为： 年间, 后于, 人口普查, 竣工, 在位, 落成, 以后, 选举, 去世, 球季,
# 2024-10-10 06:46:06,576 : INFO : 单词 之后 的最相似的 10 个单词为： 第二次世界大战, 两年, 再, 二战, 逐渐, 结束, 变得, 陆续, 几年, 发现,
# 2024-10-10 06:46:14,138 : INFO : 在第 152000 次循环的平均损失为: 1.156742
# 2024-10-10 06:46:21,709 : INFO : 在第 154000 次循环的平均损失为: 1.196218
# 2024-10-10 06:46:29,289 : INFO : 在第 156000 次循环的平均损失为: 1.141779
# 2024-10-10 06:46:36,849 : INFO : 在第 158000 次循环的平均损失为: 1.159987
# 2024-10-10 06:46:44,451 : INFO : 在第 160000 次循环的平均损失为: 1.161462
# 2024-10-10 06:46:44,452 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:46:45,322 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 家中, 父亲, 妻子, 生平, 去世, 生于, 妹妹, 家庭, 过世,
# 2024-10-10 06:46:45,358 : INFO : 单词 中国 的最相似的 10 个单词为： 内地, 古代, 新疆, 浙江, 云南, 传播, 传入, 江苏, 专家, 近代,
# 2024-10-10 06:46:45,393 : INFO : 单词 电脑 的最相似的 10 个单词为： 软体, 网路, 装置, 电子, 应用, 数码, 支援, 技术, 版本, 模拟,
# 2024-10-10 06:46:45,427 : INFO : 单词 手机 的最相似的 10 个单词为： 网路, 提供, 支援, 软件, 机, 无线, 装备, 功能, 智慧型, 网络,
# 2024-10-10 06:46:45,460 : INFO : 单词 书籍 的最相似的 10 个单词为： 书籍, 相关, 收录, 漫画, 作者, 著作, 阅读, 图书馆, 书, 传,
# 2024-10-10 06:46:45,495 : INFO : 单词 公里 的最相似的 10 个单词为： 英里, 时速, 公里, 长约, 距, 里程, 长度, 距离, 东南, 小时,
# 2024-10-10 06:46:45,529 : INFO : 单词 还 的最相似的 10 个单词为： 外, 未, 之外, 做, 设有, 用于, 表演, 想, 苏联, 留下,
# 2024-10-10 06:46:45,563 : INFO : 单词 部分 的最相似的 10 个单词为： 部分, 分为, 调整, 部份, 区域, 号线, 分成, 两, 内容, 大部分,
# 2024-10-10 06:46:45,597 : INFO : 单词 年 的最相似的 10 个单词为： 落成, 夏季, 他于, 下半年, 人口普查, 球季, 世界杯, 后于, 结束, 在位,
# 2024-10-10 06:46:45,632 : INFO : 单词 之后 的最相似的 10 个单词为： 第二次世界大战, 离开, 两年, 逐渐, 二战, 继, 多次, 结束, 再次, 失败,
# 2024-10-10 06:46:53,016 : INFO : 在第 162000 次循环的平均损失为: 1.157055
# 2024-10-10 06:47:00,339 : INFO : 在第 164000 次循环的平均损失为: 1.150659
# 2024-10-10 06:47:07,844 : INFO : 在第 166000 次循环的平均损失为: 1.127083
# 2024-10-10 06:47:15,353 : INFO : 在第 168000 次循环的平均损失为: 1.178930
# 2024-10-10 06:47:22,919 : INFO : 在第 170000 次循环的平均损失为: 1.174273
# 2024-10-10 06:47:22,920 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:47:23,795 : INFO : 单词 父亲 的最相似的 10 个单词为： 父母, 生平, 家中, 父亲, 去世, 儿子, 妹妹, 妻子, 家庭, 继承,
# 2024-10-10 06:47:23,830 : INFO : 单词 中国 的最相似的 10 个单词为： 古代, 云南, 新疆, 浙江, 江苏, 西藏, 传入, 近代, 传播, 广东,
# 2024-10-10 06:47:23,864 : INFO : 单词 电脑 的最相似的 10 个单词为： 软体, 数码, 电子, 装置, 版本, 支援, 处理, 自动, 软件, 通讯,
# 2024-10-10 06:47:23,899 : INFO : 单词 手机 的最相似的 10 个单词为： 软件, 支援, 网络, 提供, 无线, 推出, 智慧型, 平台, 网路, 功能,
# 2024-10-10 06:47:23,940 : INFO : 单词 书籍 的最相似的 10 个单词为： 书籍, 漫画, 收录, 作者, 著作, 阅读, 图书馆, 相关, 出版社, 传,
# 2024-10-10 06:47:23,975 : INFO : 单词 公里 的最相似的 10 个单词为： 英里, 公里, 时速, 长约, 里程, 距, 长度, 距离, 全长约, 公路,
# 2024-10-10 06:47:24,009 : INFO : 单词 还 的最相似的 10 个单词为： 外, 设有, 以外, 包括, 拒绝, 留下, 只能, 发现, 剩下, 用于,
# 2024-10-10 06:47:24,043 : INFO : 单词 部分 的最相似的 10 个单词为： 班次, 调整, 分为, 编号, 大部分, 号线, 分成, 延伸, 两, 内容,
# 2024-10-10 06:47:24,076 : INFO : 单词 年 的最相似的 10 个单词为： 夏季, 下半年, 出版, 后于, 他于, 毕业, 早, 拍摄, 推出, 逝世,
# 2024-10-10 06:47:24,110 : INFO : 单词 之后 的最相似的 10 个单词为： 不久, 第二次世界大战, 离开, 回到, 几年, 得知, 逐渐, 再, 结束, 打败,
# 2024-10-10 06:47:31,677 : INFO : 在第 172000 次循环的平均损失为: 1.142434
# 2024-10-10 06:47:39,205 : INFO : 在第 174000 次循环的平均损失为: 1.148911
# 2024-10-10 06:47:46,886 : INFO : 在第 176000 次循环的平均损失为: 1.133790
# 2024-10-10 06:47:54,638 : INFO : 在第 178000 次循环的平均损失为: 1.141113
# 2024-10-10 06:48:02,320 : INFO : 在第 180000 次循环的平均损失为: 1.109411
# 2024-10-10 06:48:02,321 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:48:03,195 : INFO : 单词 父亲 的最相似的 10 个单词为： 父亲, 去世, 家中, 妹妹, 父母, 生平, 长大, 过世, 家庭, 妻子,
# 2024-10-10 06:48:03,229 : INFO : 单词 中国 的最相似的 10 个单词为： 古代, 云南, 中国, 传入, 近代, 西藏, 浙江, 江苏, 内地, 当代,
# 2024-10-10 06:48:03,263 : INFO : 单词 电脑 的最相似的 10 个单词为： 软体, 装置, 通讯, 自动, 设备, 软件, 电子, 版本, 应用, 网路,
# 2024-10-10 06:48:03,297 : INFO : 单词 手机 的最相似的 10 个单词为： 网络, 软件, 推出, 网路, 智慧型, 无线, 提供, 播放, 装备, 功能,
# 2024-10-10 06:48:03,332 : INFO : 单词 书籍 的最相似的 10 个单词为： 书籍, 漫画, 收录, 阅读, 相关, 小说, 发表, 作者, 创作, 著作,
# 2024-10-10 06:48:03,366 : INFO : 单词 公里 的最相似的 10 个单词为： 英里, 公里, 时速, 距离, 长度, 长约, 距, 全长约, 东南, 里程,
# 2024-10-10 06:48:03,399 : INFO : 单词 还 的最相似的 10 个单词为： 外, 之外, 设有, 未, 人生, 拒绝, 需要, 用于, 包括, 为此,
# 2024-10-10 06:48:03,433 : INFO : 单词 部分 的最相似的 10 个单词为： 班次, 延伸, 号线, 调整, 分成, 内容, 编号, 两, 组成, 分为,
# 2024-10-10 06:48:03,466 : INFO : 单词 年 的最相似的 10 个单词为： 他于, 更名, 下半年, 发表, 以来, 后于, 年间, 至今, 夏季, 世界杯,
# 2024-10-10 06:48:03,500 : INFO : 单词 之后 的最相似的 10 个单词为： 两年, 第二次世界大战, 几年, 不久, 返回, 离开, 数年, 失败, 陆续, 回到,
# 2024-10-10 06:48:11,059 : INFO : 在第 182000 次循环的平均损失为: 1.117551
# 2024-10-10 06:48:18,375 : INFO : 在第 184000 次循环的平均损失为: 1.098656
# 2024-10-10 06:48:25,965 : INFO : 在第 186000 次循环的平均损失为: 1.103330
# 2024-10-10 06:48:33,569 : INFO : 在第 188000 次循环的平均损失为: 1.056796
# 2024-10-10 06:48:41,160 : INFO : 在第 190000 次循环的平均损失为: 1.105059
# 2024-10-10 06:48:41,162 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:48:42,040 : INFO : 单词 父亲 的最相似的 10 个单词为： 去世, 父母, 家中, 父亲, 妻子, 长大, 家庭, 生平, 过世, 弟弟,
# 2024-10-10 06:48:42,076 : INFO : 单词 中国 的最相似的 10 个单词为： 古代, 云南, 印度, 传入, 近代, 西藏, 上海, 江苏, 当代, 内地,
# 2024-10-10 06:48:42,111 : INFO : 单词 电脑 的最相似的 10 个单词为： 软体, 通讯, 软件, 设备, 应用, 网路, 自动, 开发, 电子, 新增,
# 2024-10-10 06:48:42,145 : INFO : 单词 手机 的最相似的 10 个单词为： 软件, 网路, 推出, 系列, 平台, 功能, 智慧型, 版, 无线, 机,
# 2024-10-10 06:48:42,180 : INFO : 单词 书籍 的最相似的 10 个单词为： 书籍, 漫画, 阅读, 收录, 作者, 相关, 单行本, 圣经, 著作, 创作,
# 2024-10-10 06:48:42,218 : INFO : 单词 公里 的最相似的 10 个单词为： 英里, 公里, 长度, 时速, 距, 长约, 距离, 全长约, 里程, 西南,
# 2024-10-10 06:48:42,254 : INFO : 单词 还 的最相似的 10 个单词为： 外, 之外, 设有, 人生, 以外, 说, 保留, 认为, 进行, 提到,
# 2024-10-10 06:48:42,289 : INFO : 单词 部分 的最相似的 10 个单词为： 班次, 两, 区域, 身体, 分成, 调整, 路线, 延伸, 中间, 保留,
# 2024-10-10 06:48:42,324 : INFO : 单词 年 的最相似的 10 个单词为： 他于, 下半年, 夏天, 去世, 在位, 隔, 落成, 以前, 直到, 逝世,
# 2024-10-10 06:48:42,358 : INFO : 单词 之后 的最相似的 10 个单词为： 离开, 去世, 几年, 两年, 回到, 数年, 进入, 过世, 继, 一段时间,
# 2024-10-10 06:48:49,944 : INFO : 在第 192000 次循环的平均损失为: 1.063899
# 2024-10-10 06:48:57,467 : INFO : 在第 194000 次循环的平均损失为: 1.105784
# 2024-10-10 06:49:05,013 : INFO : 在第 196000 次循环的平均损失为: 1.081990
# 2024-10-10 06:49:12,547 : INFO : 在第 198000 次循环的平均损失为: 1.069113
# 2024-10-10 06:49:20,063 : INFO : 在第 200000 次循环的平均损失为: 1.105460
# 2024-10-10 06:49:20,065 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:49:20,939 : INFO : 单词 父亲 的最相似的 10 个单词为： 父母, 家中, 家庭, 去世, 妻子, 长大, 父亲, 妹妹, 生于, 孩子,
# 2024-10-10 06:49:20,974 : INFO : 单词 中国 的最相似的 10 个单词为： 古代, 印度, 内地, 云南, 西藏, 江苏, 传入, 近代, 浙江, 中国,
# 2024-10-10 06:49:21,008 : INFO : 单词 电脑 的最相似的 10 个单词为： 软体, 应用, 通讯, 软件, 网路, 设备, 装置, 程式, 数位, 自动,
# 2024-10-10 06:49:21,042 : INFO : 单词 手机 的最相似的 10 个单词为： 网路, 软件, 推出, 无线, 智慧型, 电影, 机, 系列, 平台, 功能,
# 2024-10-10 06:49:21,075 : INFO : 单词 书籍 的最相似的 10 个单词为： 书籍, 漫画, 收录, 作者, 著作, 阅读, 写, 小说, 创作, 相关,
# 2024-10-10 06:49:21,109 : INFO : 单词 公里 的最相似的 10 个单词为： 英里, 长度, 时速, 距, 长约, 距离, 公里, 里程, 全长约, 约,
# 2024-10-10 06:49:21,142 : INFO : 单词 还 的最相似的 10 个单词为： 之外, 外, 说, 人生, 设有, 以外, 包括, 用于, 大部分, 提到,
# 2024-10-10 06:49:21,176 : INFO : 单词 部分 的最相似的 10 个单词为： 区域, 两, 地区, 部分, 中间, 延伸, 分成, 身体, 保留, 大部分,
# 2024-10-10 06:49:21,211 : INFO : 单词 年 的最相似的 10 个单词为： 夏季, 夏天, 以来, 下半年, 年间, 以前, 落成, 隔, 至今, 完工,
# 2024-10-10 06:49:21,244 : INFO : 单词 之后 的最相似的 10 个单词为： 不久, 去世, 两年, 便, 继, 数年, 二战, 逐渐, 变成, 打开,
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
