# %%
"""
  @FileName：Skip_gram_TF.py
  @Author：Excelius
  @CreateTime：2024/10/6 11:37
  @Company: None
  @Description：
"""
import collections
import math
import os
import logging
import random

import numpy as np
import tensorflow.compat.v1 as tf
from importlib import reload
from sklearn.manifold import TSNE
import pickle

"""----------参数----------"""
colab_cwd = '/content'
if os.getcwd() == colab_cwd:
    # 处理好的文本存储在谷歌云盘
    file_path = os.path.join(os.getcwd(), "drive", "MyDrive", "data", "txt", "wiki_seg.txt")
else:
    # 本地的文件路径
    file_path = os.path.join(os.getcwd(), "data", "txt", "wiki_seg.txt")
# 每次迭代将使用 256 个样本进行参数更新
batch_size = 256
# 单词转为稠密向量的维度
embedding_size = 350
# 左右考虑多少个单词
skip_window = 4
# 重复使用输入以生成标签的次数
num_skips = 8

# 用来抽取的验证单词数
valid_size = 10
# 验证单词只从频数最高的 100 个单词中抽取
valid_window = 100
# 需要验证的单词
valid_has_word = ['父亲', '中国', '电脑', '手机', '书籍', '公里', '还', '部分', '年', '之后']
# valid_examples = np.array(random.sample(range(valid_window), valid_size))
# valid_examples = np.random.choice(valid_window, valid_size, replace=False)
# 负采样的噪声单词的数量
num_sampled = 64

"""----------logging配置----------"""
# 使用 logging.info 打印信息，colab 需要 reload() 函数，否则无法打印
reload(logging)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

"""----------数据处理----------"""


def read_data(filename):
    """
    从本地文件中读取数据，
    @param filename:
    @return:
    """
    logging.info("开始读取文件：" + filename)
    with open(filename, "r", encoding="utf-8") as f:
        # 一次性读取所有的行，返回一个列表
        seg_content = f.readlines()
        seg_words = []
        # 将单词都存放到seg_words列表中，不去重，方便下一步建立以词频为基础的词表
        for i in range(len(seg_content)):
            if i % 5000 == 0:
                logging.info("当前读取到第 " + str(i) + " 行，部分数据为: " + str(seg_content[i][:50]))
            # 获取当前行词的列表，使用strip()函数过滤空格包括换行符或者制表符
            seg_words.extend(seg_content[i].strip().split(" "))
    return seg_words


all_words_list = read_data(file_path)


def build_dataset(words, size):
    """
    创建词表，包括原始词表、转换后的索引词表、单词-索引表和索引-单词表
    @param words: 原始词表
    @param size: 高频词词表长度
    @return: 索引词表、原始词表、单词-索引词表、索引-单词词表
    """
    # 初始化 count 列表，其中 UNK 代表 unknown, 即高频词表以外的词
    _count = [['UNK', -1]]
    # 统计词频，只取前 vocabulary_size 个高频词, 格式为：('词', 词频)
    _word_collection = collections.Counter(words)
    logging.info('所有词的数量为：' + str(len(_word_collection)))
    _count.extend(_word_collection.most_common(size - 1))
    logging.info("高频词表前 20 个数据为数据为: " + str(_count[:20]))
    # 构建字典，将词转化为索引, 词典顺序为高频词顺序, 格式为('词', 索引), 其中索引从 0 开始
    _dictionary = dict()
    for _word, _ in _count:
        _dictionary[_word] = len(_dictionary)
    # 将词转化为索引存储到_data中, 词在高频词词典的话，索引为高频词词典的索引, 如果词不在字典中, 则转化为 UNK
    # 此时 _data 就是原来词的列表的索引列表
    _data = list()
    unk_count = 0
    for _word in words:
        if _word in _dictionary:
            index = _dictionary[_word]
        else:
            index = 0
            unk_count += 1
        _data.append(index)
    _count[0][1] = unk_count
    # 构建反向字典, 可以快速从词索引转化为词即 (索引-'词')
    _reverse_dictionary = dict(zip(_dictionary.values(), _dictionary.keys()))
    return _data, _count, _dictionary, _reverse_dictionary


# 高频词词表大小, 对于 4w 的切片， 10w 词表的结果较好
vocabulary_size = 800000
# 构建词表
data, count, dictionary, reverse_dictionary = build_dataset(all_words_list, vocabulary_size)
logging.info('所有词的数量为：' + str(len(count)))
logging.info('含 UNK 的前 20 个高频词' + str(count[: 20]))
logging.info('查看索引与词的映射：')
logging_str = ''.join(
    [f"{idx} : {word}, " for idx, word in zip(data[:10], [reverse_dictionary[i] for i in data[:10]])])
logging.info(logging_str)
# 完善验证单词的索引
valid_examples = []
# 如果待验证词在此表中，那么直接获得索引，否则指定为 unknown
for word in valid_has_word:
    if dictionary.get(word, None) is not None:
        valid_examples.append(dictionary[word])
    else:
        valid_examples.append(0)

# 删除原始词表，节省内存
del all_words_list
data_index = 0


def generate_batch(_batch_size, _num_skips, _skip_window):
    """
    生成训练用的 batch 数据以及标签数据，其中 batch 是 上下文， label 是 目标词
    @param _batch_size: batch 的大小
    @param _num_skips: 目标词的上下文窗口大小（只有一半）
    @param _skip_window: 目标词的上下文窗口大小（只有一半）
    @return: 生成的 batch 数据 和 label 数据
    """
    global data_index
    assert _batch_size % _num_skips == 0
    assert _num_skips <= 2 * _skip_window
    # 初始化二维数组, 行数为 _batch_size，列数为 2 * half_window_size, 数据类型为 int32
    _batch = np.ndarray(shape=(_batch_size), dtype=np.int32)
    _labels = np.ndarray(shape=(_batch_size, 1), dtype=np.int32)
    span = 2 * _skip_window + 1
    len_data = len(data)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len_data
    for i in range(_batch_size // _num_skips):
        target = _skip_window  # target label at the center of the buffer
        targets_to_avoid = [_skip_window]
        for j in range(_num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            _batch[i * _num_skips + j] = buffer[_skip_window]
            _labels[i * _num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len_data
    return _batch, _labels


"""----------训练 & 验证----------"""
# 创建默认的 graph
graph = tf.Graph()
with graph.as_default():
    '''-----输入-----'''
    # 创建一个 TensorFlow 占位符的，类型为 32 位整数，大小为 batch_size 的一维张量
    # train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    # 创建一个 TensorFlow 占位符的，类型为 32 位整数，大小为 batch_size x 1 的二维张量
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    # 创建常量张量, 值为 valid_examples 列表中的元素, 制定了数据类型, 用于后续作为固定输入
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    '''-----变量-----'''
    # 词嵌入矩阵, 形状为 [vocabulary_size, embedding_size], 通过训练，嵌入矩阵会学习到每个词的分布式表示（即词向量）
    # tf.random.uniform() 用于从均匀分布中随机初始化嵌入向量，范围是 [-1.0, 1.0]。给每个词的嵌入向量的初始值是在 -1 到 1 之间的随机数。
    embeddings = tf.Variable(tf.random.uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    # softmax 层的权重矩阵，形状为 [vocabulary_size, embedding_size], 用于在通过模型训练时，将词嵌入向量映射到词汇表中每个词的概率分布
    # tf.random.truncated_normal() 用于从截断的正态分布中随机初始化权重。
    # 标准差 stddev=1.0 / math.sqrt(embedding_size) 是一种常见的初始化方式，它有助于在训练开始时使网络中的权重分布更加合理，避免梯度消失或梯度爆炸问题。
    softmax_weights = tf.Variable(
        tf.random.truncated_normal([vocabulary_size, embedding_size],
                                   stddev=1.0 / math.sqrt(embedding_size)))
    # softmax_biases 是 softmax 层的偏置项，形状为 [vocabulary_size]，表示每个词汇都有一个对应的偏置
    # tf.zeros([vocabulary_size]) 使用全零初始化偏置项。这是常见的初始化方式，偏置值会在训练过程中更新
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    '''-----模型-----'''
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # 转化变量输入，适配NCE
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]), dtype=tf.float32)

    loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights,
                                         biases=nce_biases,
                                         inputs=embed,
                                         labels=train_labels,
                                         num_sampled=num_sampled,
                                         num_classes=vocabulary_size))

    # # 将嵌入矩阵每行元素求和得到一个向量
    # inputs = tf.reduce_sum(embed, 1)
    # # 计算 softmax 损失，每次使用负标签样本
    # loss = tf.reduce_mean(
    #     tf.nn.sampled_softmax_loss(
    #         softmax_weights, softmax_biases, train_labels, embed, num_sampled, vocabulary_size
    #     )
    # )
    '''-----Optimizer-----'''
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
    embeddings_2 = (normalized_embeddings + softmax_weights) / 2.0
    norm_ = tf.sqrt(tf.reduce_sum(tf.square(embeddings_2), 1, keep_dims=True))
    normalized_embeddings_2 = embeddings_2 / norm_

num_steps = 1000001

with tf.Session(graph=graph) as session:
    if int(tf.version.VERSION.split('.')[1]) > 11:
        tf.compat.v1.global_variables_initializer().run()
    else:
        tf.initialize_all_variables().run()
    logging.info("初始化完成...")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            _batch_size=batch_size,
            _num_skips=num_skips,
            _skip_window=skip_window
        )
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val
        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            logging.info("在第 %d 次循环的平均损失为: %f" % (step, average_loss))
            average_loss = 0

        if step % 10000 == 0:
            logging.info("验证单词与最相似的 10 个单词：")
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 10  # 取最相似的 10 个单词
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "单词 %s 的最相似的 10 个单词为：" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                logging.info(log_str)
    final_embeddings = normalized_embeddings.eval()
    final_embeddings_2 = normalized_embeddings_2.eval()  # 更好的结果

"""----------结果----------"""
# 后续需要处理的点的数量
num_points = 10000
# 创建了 t-SNE 对象 tsne，n_components 指定降维后的维度为2，init 指定了初始化方法为 pca，n_iter 指定了最大迭代次数为 5000
tsne_2 = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
# 对 final_embeddings 中的前 400 个嵌入（从索引 1 到 400）进行 t-SNE 降维，并将结果存储在 two_d_embeddings 中
two_d_embeddings = tsne_2.fit_transform(final_embeddings[1:num_points + 1, :])
two_d_embeddings_2 = tsne_2.fit_transform(final_embeddings_2[1:num_points + 1, :])
if os.getcwd() == colab_cwd:
    # 处理好的文本存储在谷歌云盘
    output_path = os.path.join(os.getcwd(), "drive", "MyDrive", "data", "embedding_skip_gram.pkl")
else:
    # 本地的文件路径
    output_path = os.path.join(os.getcwd(), "data", "embedding_skip_gram.pkl")
with open(output_path, 'wb') as f:
    pickle.dump([final_embeddings[:800000, :], final_embeddings_2[:800000, :], two_d_embeddings, two_d_embeddings_2, reverse_dictionary], f)
# Out:
# 2024-10-10 06:33:42,226 : INFO : 开始读取文件：/content/drive/MyDrive/data/txt/wiki_seg.txt
# 2024-10-10 06:33:47,057 : INFO : 当前读取到第 0 行，部分数据为: 欧几里得 西元前 三 世纪 古希腊 数学家 现在 认为 几何 父 此画 拉斐尔 作品 雅典 学院 数
# 2024-10-10 06:33:47,246 : INFO : 当前读取到第 5000 行，部分数据为: 北京军区 管辖 范围 北京市 大 军区 机关 天津市 河北省 山西省 内蒙古自治区 东四 盟外 中国
# 2024-10-10 06:33:47,445 : INFO : 当前读取到第 10000 行，部分数据为: 跆拳道 跆 唐手 空手道 融合 武术 跆拳道 年 汉城 奥运 首次 列为 示范 项目 年 巴塞隆纳
# 2024-10-10 06:33:47,597 : INFO : 当前读取到第 15000 行，部分数据为: 池鹭 学名 又名 沙鹭 花洼子 交 胪 中国 池鹭 紫 邬头 红毛 鹭 沼鹭 围螺鹭 田牛奴 茭鸡
# 2024-10-10 06:33:47,740 : INFO : 当前读取到第 20000 行，部分数据为: 德国 级 装甲 舰 或称 德意志 级 装甲 舰 德国 海军 年代 符合 凡尔赛 和约 同级 舰共 三
# 2024-10-10 06:33:47,885 : INFO : 当前读取到第 25000 行，部分数据为: 父名 英语 姓名 一种 人 父名 取自 父亲 取自 母亲 名字 称作 语言 中 父名 东 斯拉夫 民
# 2024-10-10 06:33:48,015 : INFO : 当前读取到第 30000 行，部分数据为: 保罗 约 田 立克 哲学家 新 保罗 主义者 视为 美国 存在主义 代表 人物 名称 音译 中国 大
# 2024-10-10 06:33:48,144 : INFO : 当前读取到第 35000 行，部分数据为: 赵汝 伯可 两 浙东 路 天台县 人 宋朝 宗室 进士 出身 生平 绍熙 元年 将士 郎 次年 铨试
# 2024-10-10 06:33:48,268 : INFO : 当前读取到第 40000 行，部分数据为: 飞马 座 或称 柏勒洛丰 一颗 位于 飞马 座 距离 地球 约 光年 系 外行星 飞马 座 运转 系
# 2024-10-10 06:33:48,384 : INFO : 当前读取到第 45000 行，部分数据为: 贿赂 联合国 反腐败 公约 贿赂 包括 行贿 收贿 指 个人 利用 职务 上 便利 索取 人财物 非
# 2024-10-10 06:33:48,498 : INFO : 当前读取到第 50000 行，部分数据为: 钱 棨 振威 湘 舲 曰 一字 湘 舲 江苏省 苏州 府 长洲 县 今 江苏省 苏州市 无锡 钱氏
# 2024-10-10 06:33:48,611 : INFO : 当前读取到第 55000 行，部分数据为: 人类 发声 构造 侧视图 此图 未 标示 声门 位于 标示 咽喉 通路 喉 之间 两瓣 声带 之间
# 2024-10-10 06:33:48,721 : INFO : 当前读取到第 60000 行，部分数据为: 伊莉莎白 莉斯 博登 一名 美国 超级 人瑞 日至 终年 生前 居住 美国 田纳西州 孟菲斯市 日起
# 2024-10-10 06:33:48,834 : INFO : 当前读取到第 65000 行，部分数据为: 域 陀 华迪斯 阿里 巴斯 前 西班牙 足球 运动员 司职 守门员 曾效力 西甲 班霸 巴塞罗那 英
# 2024-10-10 06:33:48,934 : INFO : 当前读取到第 70000 行，部分数据为: 调查 报导 经常 涉及 犯罪 腐败 形式 丑闻 历史 世纪 尤其 美国 最为 显著 直到 年代 揭露
# 2024-10-10 06:33:49,038 : INFO : 当前读取到第 75000 行，部分数据为: 顽皮 家族 华视 经典 电视节目 李厚蓉 制作 主要 介绍 分布 世界各地 动物 影片 介绍 外表
# 2024-10-10 06:33:49,142 : INFO : 当前读取到第 80000 行，部分数据为: 拉 里奥 西班牙 单省 自治区 总面积 平方公里 年 总人口 首府 洛 格罗 尼奥 拉 里奥 连接
# 2024-10-10 06:33:49,239 : INFO : 当前读取到第 85000 行，部分数据为: 屏东 平原 屏东 平原 或称 下 淡水 平原 台湾 南部 一处 陷落 冲积平原 面积 约 平方公里
# 2024-10-10 06:33:49,337 : INFO : 当前读取到第 90000 行，部分数据为: 中土 佐 町 位于 日本 高 知县 中西部 町 隶属于 高冈 郡 东边 面向 土佐湾 四万 十川 流
# 2024-10-10 06:33:49,427 : INFO : 当前读取到第 95000 行，部分数据为: 黑 喇嘛 丹毕 坚赞 丹毕 坚赞 又名 黑 喇嘛 假 喇嘛 丹毕 贾 俄国 卫拉特 蒙古 传奇人物
# 2024-10-10 06:33:49,523 : INFO : 当前读取到第 100000 行，部分数据为: 年 浪漫 奇幻 冒险 电影 由马修 范恩 指导 电影 改编自 尼尔 盖曼 年 同名 小说 绘图 发行
# 2024-10-10 06:33:49,616 : INFO : 当前读取到第 105000 行，部分数据为: 稚内 灯塔 进一步 被选为 日本 灯塔 灯塔 南 延到 西侧 海岸线 宗谷 海峡 方向 望见 利尻岛
# 2024-10-10 06:33:49,713 : INFO : 当前读取到第 110000 行，部分数据为: 国旗 旗帜 日期 用途 设计 叙述 现今 亚美尼亚 国旗 由上至下 依序 红 橘三色 横旗 蓝色 象
# 2024-10-10 06:33:49,804 : INFO : 当前读取到第 115000 行，部分数据为: 世纪 文艺复兴 政治 经济 发生 剧变 哲学 其受 黑死病 日后 科学 艺术 文化 领域 埋 下 种
# 2024-10-10 06:33:49,896 : INFO : 当前读取到第 120000 行，部分数据为: 山东 鲁能泰山 足球 俱乐部 赛季 记录 山东 鲁能泰山 足球 俱乐部 征战 赛季 情况 年 山东
# 2024-10-10 06:33:49,983 : INFO : 当前读取到第 125000 行，部分数据为: 谜语 指 字面 无法解释 语句 暗射 事物 文字 供 人 猜测 隐语 需要 推敲 猜测 答案 历史
# 2024-10-10 06:33:50,067 : INFO : 当前读取到第 130000 行，部分数据为: 夏永豪 香港 教育家 现任 香港 圣公会 大主教 教育 顾问 年 年任 圣保罗 书院 校长 期间 曾
# 2024-10-10 06:33:50,157 : INFO : 当前读取到第 135000 行，部分数据为: 战龙 四驱 一部 中国 制作 迷你 四驱车 动画 故事 地点 制作 公司 奥飞 动漫 企业 剧情 大
# 2024-10-10 06:33:50,259 : INFO : 当前读取到第 140000 行，部分数据为: 纪尧姆 迪费 译 杜飞 或作 法国 弗莱 芒 作曲家 生平 世纪 法 兰德斯 最 伟大 作曲家 其后
# 2024-10-10 06:33:50,348 : INFO : 当前读取到第 145000 行，部分数据为: 南部 健一 日本 力学 家 等离子体 物理学家 东北大学 荣誉 教授 退休 工学 博士 主要 研究
# 2024-10-10 06:33:50,433 : INFO : 当前读取到第 150000 行，部分数据为: 美国 白人 指 认为 自称为 白人 美国 人 白种人 包括 构成 美国 最大 族裔 年 美国 人口普
# 2024-10-10 06:33:50,519 : INFO : 当前读取到第 155000 行，部分数据为: 美国 物理 联合会 缩写 物理学 领域 学术性 组织 成立 官方 正式 翻译 美国 物理 联合会 美
# 2024-10-10 06:33:50,610 : INFO : 当前读取到第 160000 行，部分数据为: 蒋任宏 香港 执业 大 律师 曾 公务员 年任 香港 邮政 署 署长 年 年任 香港 设计 中心 行
# 2024-10-10 06:33:50,696 : INFO : 当前读取到第 165000 行，部分数据为: 褐 鹈鹕 学名 鹈鹕 科 鸟类 新大陆 三种 鹈鹕 唯二会 潜水 捕猎 鹈鹕 大西洋 沿岸 鸟 分布
# 2024-10-10 06:33:50,780 : INFO : 当前读取到第 170000 行，部分数据为: 核工程 中 易 裂变 材料 定义 带有 中子 减速剂 热反应堆 不 带有 中子 减速剂 快速 反应堆
# 2024-10-10 06:33:50,867 : INFO : 当前读取到第 175000 行，部分数据为: 年 威尔士 公开赛 职业 斯诺克 积分 排名赛 比赛 时间 日至 地点 纽波特 中心 马克 塞尔 决
# 2024-10-10 06:33:50,974 : INFO : 当前读取到第 180000 行，部分数据为: 小行星 索 科罗 林肯 近地 小行星 研究 小组 小行星 基特 峰 太空 监视 小行星 索 科罗 林
# 2024-10-10 06:33:51,055 : INFO : 当前读取到第 185000 行，部分数据为: 请多关照 张 单曲 日本 皇冠 日 发售 概要 年 发行 第三张 单曲 发行 形态 延续 前作 抱歉
# 2024-10-10 06:33:51,141 : INFO : 当前读取到第 190000 行，部分数据为: 威廉 杰克 苏格兰 植物学家 威廉 纳萨 尼尔 瓦立池 一起 当地 植物 进行 研究 陪同 斯坦福
# 2024-10-10 06:33:51,227 : INFO : 当前读取到第 195000 行，部分数据为: 德米 安 毕齐 纳 赫拉 一名 墨西哥 男演员 父母 兄弟 都 演员 妻子 歌手 电视 作品 电视
# 2024-10-10 06:33:51,299 : INFO : 当前读取到第 200000 行，部分数据为: 年 年 西班牙 足球 甲级联赛 参赛 球队 毕尔巴鄂 竞技 马德里 竞技 巴塞罗那 塞尔塔 埃尔切
# 2024-10-10 06:33:51,370 : INFO : 当前读取到第 205000 行，部分数据为: 日本 女子 偶像 组合 早安 少女 组 张 单曲 日 发售 概要 电视台 节目 主题曲 面曲 早安
# 2024-10-10 06:33:51,451 : INFO : 当前读取到第 210000 行，部分数据为: 开台 福德宫 初 名为 打狗 开台 福德宫 西 元 昭和 八年 重修 完后 更名 高雄市 哨 船头
# 2024-10-10 06:33:51,533 : INFO : 当前读取到第 215000 行，部分数据为: 第二届 夏 赫里 尔 内阁 印度尼西亚共和国 届 内阁 苏丹 夏 赫里 尔 总理 领导 第二届 内阁
# 2024-10-10 06:33:51,613 : INFO : 当前读取到第 220000 行，部分数据为: 海特 亨 托特 圣扬斯 文艺复兴 时期 欧洲 尼德兰 艺术家 英年早逝 代表 画作 仍 留存 至今
# 2024-10-10 06:33:51,690 : INFO : 当前读取到第 225000 行，部分数据为: 新浪 微博 腾讯 微博 封 许昌县 男子 杀妻 被判 死缓 现代 消费 导报 分 辽宁省 辽阳市 灯
# 2024-10-10 06:33:51,765 : INFO : 当前读取到第 230000 行，部分数据为: 蒂姆 杜安 哈达威 美国 联盟 前 职业 篮球 运动员 年 选秀 中 轮 顺位 金州 勇士 选中 年
# 2024-10-10 06:33:51,854 : INFO : 当前读取到第 235000 行，部分数据为: 歌连臣 托马斯 伯纳德 柯 林森 英国皇家 工兵 部队 测量师 初期 英国 作 测绘 工作 后 前往
# 2024-10-10 06:33:51,946 : INFO : 当前读取到第 240000 行，部分数据为: 中华民国 第一 配偶 包括 第一夫人 第一 先生 中华民国 总统 配偶 非正式 职称 现任 总统 赖
# 2024-10-10 06:33:52,028 : INFO : 当前读取到第 245000 行，部分数据为: 江宁区 博物馆 成立 现为 国家 三级 博物馆 江宁区 博物馆 江宁 博物馆 东晋 历史 文化 博物
# 2024-10-10 06:33:52,115 : INFO : 当前读取到第 250000 行，部分数据为: 埃米尔 霍尔斯特 丹麦 男子 羽毛球 运动员 简历 埃米尔 霍尔斯特 岁 时 接触 羽毛球 运动 岁
# 2024-10-10 06:33:52,197 : INFO : 当前读取到第 255000 行，部分数据为: 南奥塞梯 共和国 国歌 亦 第一句 歌词 称为 亲爱 奥塞梯 南奥塞梯 采用 国歌 日 启用 词作者
# 2024-10-10 06:33:52,276 : INFO : 当前读取到第 260000 行，部分数据为: 从荷 李活 道 元 创方 晚上 元 创方 楼 多用途 会堂 元 创方 意 已婚 警察 宿舍 香港 创
# 2024-10-10 06:33:52,358 : INFO : 当前读取到第 265000 行，部分数据为: 中 法 实业银行 中 法 合资 银行 成立 中国 办事处 设在 上海 欧洲 办事处 设在 巴黎 银行
# 2024-10-10 06:33:52,447 : INFO : 当前读取到第 270000 行，部分数据为: 成立 公司 名称 来源于 法语 缩写 公司 月 合并 更名 月 完成 收购 之后 公司 名称 改 回
# 2024-10-10 06:33:52,534 : INFO : 当前读取到第 275000 行，部分数据为: 阮氏路 越南 后 黎朝 女官 诗人 大臣 阮 廌 妾 今属 太平 省兴 河县 新礼社 阮氏路 出身
# 2024-10-10 06:33:52,617 : INFO : 当前读取到第 280000 行，部分数据为: 本名 科瓦林 文萨塔 汉名 杨芸 晴 泰籍 华语 女歌手 演员 前 组合 主唱 领舞 年 参加 创造
# 2024-10-10 06:33:52,702 : INFO : 当前读取到第 285000 行，部分数据为: 撒旦 坑 英国 科幻 电视剧 异世 奇人 系列 日 首播 这集 剧本 编写 执导 演员 方面 大卫
# 2024-10-10 06:33:52,783 : INFO : 当前读取到第 290000 行，部分数据为: 荃湾 愉 景新城 分校 将军 澳 分校 已 搬离 图中 所示 位置 湾仔 庄士敦 道 分校 已 结业
# 2024-10-10 06:33:52,871 : INFO : 当前读取到第 295000 行，部分数据为: 七龙珠 复活 融合 悟空 贝 吉塔 英语 七龙珠 日 上映 部 剧场版 动画 故事 时间 魔 人布欧
# 2024-10-10 06:33:52,947 : INFO : 当前读取到第 300000 行，部分数据为: 杉户 彰 日本 漫画家 代表作 集英社 周刊 连载 仆 少女 来历 投稿 短篇 海之星 入选 小学
# 2024-10-10 06:33:53,025 : INFO : 当前读取到第 305000 行，部分数据为: 费尔特 拉格 特 环形山 月球 背面 一座 古老 大 撞击 坑 约 形成 于前 酒海纪 名称 取自
# 2024-10-10 06:33:53,106 : INFO : 当前读取到第 310000 行，部分数据为: 光明 山 地铁站 代号 新加坡 地铁 汤申 东 海岸线 上 车站 位于 新加坡 本岛 碧山 规划区
# 2024-10-10 06:33:53,176 : INFO : 当前读取到第 315000 行，部分数据为: 证书 透明度 简称 称 证书 透明 证书 透明化 目的 监测 审计 数字证书 透过 证书 日志 监控
# 2024-10-10 06:33:53,259 : INFO : 当前读取到第 320000 行，部分数据为: 中国人民武装警察部队 监察 委员会 合署 办公 简称 武警部队 纪委 监委 沿革 中国人民武装警察部
# 2024-10-10 06:33:53,334 : INFO : 当前读取到第 325000 行，部分数据为: 阿波罗 号 拍摄 维里 陨石坑 斜视图 维里 陨石坑 名称 取自 美国 天文学家 年 国际天文学联合
# 2024-10-10 06:33:53,411 : INFO : 当前读取到第 330000 行，部分数据为: 点 新闻 韩国 旗舰 新闻节目 韩国 标准 时间 平日 周末 播放 这节 新闻 日 启播 日 开播
# 2024-10-10 06:33:53,486 : INFO : 当前读取到第 335000 行，部分数据为: 马文东 直隶 今 河北 安平 人 中华人民共和国 政治 人物 曾任 云南省 人大常委会 副 主任 生
# 2024-10-10 06:33:53,564 : INFO : 当前读取到第 340000 行，部分数据为: 欧洲 室内 五人制 足球 冠军联赛 成立 当年 赛事 名称 欧洲 室内 五人制 足球 杯 取代 年
# 2024-10-10 06:33:53,644 : INFO : 当前读取到第 345000 行，部分数据为: 睡鼠 英国 作家 路易斯 卡罗 儿童 奇幻 小说 爱丽丝 梦游 仙境 里 虚构 人物 第七章 疯狂
# 2024-10-10 06:33:53,723 : INFO : 当前读取到第 350000 行，部分数据为: 茅丽瑛 浙江 杭州人 中国共产党 党员 中国 职业妇女 俱乐部 主席 党支部 委员 生平 茅丽瑛 出
# 2024-10-10 06:33:53,806 : INFO : 当前读取到第 355000 行，部分数据为: 日世嘉 平台 上 发售 动作 冒险游戏 同属 人中之龙 系列 采 相同 世界观 游戏 背景 亦 设定
# 2024-10-10 06:33:53,884 : INFO : 当前读取到第 360000 行，部分数据为: 月 东京 电玩展 上 公布 发行 周年 纪念日 全球 限量 发售 规格 功能 该机 缩小 版 外观
# 2024-10-10 06:33:53,960 : INFO : 当前读取到第 365000 行，部分数据为: 难陀 义为 印度 文化圈 常见 名 现代 北京 国语 译 南 达 南字用 错 韵尾 达字 误用 入声
# 2024-10-10 06:33:54,036 : INFO : 当前读取到第 370000 行，部分数据为: 花泽樱 日本 女性 声优 京都府 出身 所属 主要 日本 成人 游戏 配音 人物 喜欢 玩 美少女
# 2024-10-10 06:33:54,122 : INFO : 当前读取到第 375000 行，部分数据为: 美国国防部 年 拍摄 阿勒山 异物 照片 美国 锁眼 间谍卫星 拍摄 阿勒山 照片 红圈 处 阿勒山
# 2024-10-10 06:33:54,208 : INFO : 当前读取到第 380000 行，部分数据为: 掸 泰 地块 又称 掸邦 地块 滇缅 马苏 地块 滇缅 马来亚 地块 中国 境内 称为 保山 地块
# 2024-10-10 06:33:54,290 : INFO : 当前读取到第 385000 行，部分数据为: 北京 飞往 洛杉矶 号 班机 旅客 稀少 条目 记录 冠状病毒 病疫情 航空业 影响 防控 冠状病毒
# 2024-10-10 06:33:54,372 : INFO : 当前读取到第 390000 行，部分数据为: 湖北省公安厅 历史沿革 成立 湖北省人民政府 公安厅 对内 称 中共湖北省委 社会部 内设 秘书 机
# 2024-10-10 06:33:54,451 : INFO : 当前读取到第 395000 行，部分数据为: 这是 安哥拉 城市 列表 安哥拉 名称 年 人口 安布 里 什 本戈 安杜洛 比耶 拜伦 万博 巴隆
# 2024-10-10 06:33:54,528 : INFO : 当前读取到第 400000 行，部分数据为: 苋菜 红 又称 酸性 红 一种 修改 红色 偶氮染料 食用 色素 化妆品 着色 用途 名称 取自 苋
# 2024-10-10 06:33:54,604 : INFO : 当前读取到第 405000 行，部分数据为: 微蛛 亚科 学名 为皿 蛛科 六个 亚科 当中 最大 亚科 如同 皿 蛛科 物种 英国 俗语 称为
# 2024-10-10 06:33:54,678 : INFO : 当前读取到第 410000 行，部分数据为: 任尚碑 称为 汉平 戎碑 汉 永元 五年 碑 南 还 伊吾 今 新疆 哈密 后于 永元 五年 公元
# 2024-10-10 06:33:54,755 : INFO : 当前读取到第 415000 行，部分数据为: 八斗子 清代 官煤 风坑 别名 清国井 台湾 第一口 官煤 创建 清光绪 二年 兵轮用 煤 清朝 后
# 2024-10-10 06:33:54,834 : INFO : 当前读取到第 420000 行，部分数据为: 土龙 之歌 译 卧底 威龙 日本 漫画家 创作 青年 漫画 周刊 号 号 连载 之后 移 刊到 号
# 2024-10-10 06:33:54,905 : INFO : 当前读取到第 425000 行，部分数据为: 一部 年 上映 台湾 爱情喜剧 奇幻 电影 改编自 九把刀 同名 小说 九把刀 亲自 执导 兼 编剧
# 2024-10-10 06:33:54,977 : INFO : 当前读取到第 430000 行，部分数据为: 香槟 伯国 于格 一世 第一位 称号 香槟 伯爵 贵族 亨利 一世 时期 该伯国 成为 法国 最 富
# 2024-10-10 06:33:55,050 : INFO : 当前读取到第 435000 行，部分数据为: 年 杜拜 世界杯 一项 杜拜 美丹 马场 举行 马匹 赛事 亦 该项 赛事 届 赛事 赛事 总 奖金
# 2024-10-10 06:33:55,125 : INFO : 当前读取到第 440000 行，部分数据为: 哥伦布 宫 这项 世界遗产 一部分 建于 年 年间 主要 采用 哥特式 文艺复兴 风格 克里斯托弗
# 2024-10-10 06:33:55,195 : INFO : 当前读取到第 445000 行，部分数据为: 发展 型 国家 硬性 国家 国际 政治经济学 学者 用来 指代 这种 资本主义 模式 有时 称为 国
# 2024-10-10 06:33:55,271 : INFO : 当前读取到第 450000 行，部分数据为: 江 德兴 新竹 州 苗栗 郡 人 日本 名古屋 帝国 大学 医学部 毕业 台中市 健元 医院院长 日
# 2024-10-10 06:33:55,355 : INFO : 当前读取到第 455000 行，部分数据为: 物理学 困惑 理论 物理学家 李 斯莫林于 斯莫林 认为 弦 理论 似乎 存在 严重 缺陷 需要 方
# 2024-10-10 06:33:55,433 : INFO : 当前读取到第 460000 行，部分数据为: 皮博迪 指 皮博迪 能源 世界 上 最大 私人 煤炭企业 指 图书馆 乔治 皮博迪 图书馆 位于 美
# 2024-10-10 06:33:55,509 : INFO : 当前读取到第 465000 行，部分数据为: 北俄 干涉 又称 北俄 远征 大 天使 战役 摩尔 曼 部署 外国 军队 站 俄国 白军 一边 介入
# 2024-10-10 06:33:55,584 : INFO : 当前读取到第 470000 行，部分数据为: 全球 稍 超过 分 农业 产生 温室 气体 排放 数量 庞大 农业 林业 土地利用 三个 部门 排放
# 2024-10-10 06:33:55,660 : INFO : 当前读取到第 475000 行，部分数据为: 全国 党代会 集会 场 圣 光大 教堂 摄于 光明 大 教堂 纳粹德国 年 建筑师 阿尔伯特 施 佩
# 2024-10-10 06:33:55,732 : INFO : 当前读取到第 480000 行，部分数据为: 现场 演出 列表 公演 演唱会 线上 媒体 广播电台 电视 演出 不在此列 请参阅 影视作品 列表
# 2024-10-10 06:34:37,390 : INFO : 所有词的数量为：3103064
# 2024-10-10 06:34:50,780 : INFO : 高频词表前 20 个数据为数据为: [['UNK', -1], ('年', 1574104), ('中', 842526), ('后', 744954), ('日', 689411), ('小行星', 667006), ('人', 545308), ('月', 460288), ('上', 445179), ('时', 378960), ('不', 351334), ('日本', 346432), ('中国', 335412), ('美国', 323930), ('会', 320299), ('都', 304521), ('大', 295780), ('香港', 283194), ('号', 280674), ('站', 273673)]
# 2024-10-10 06:35:45,692 : INFO : 所有词的数量为：800000
# 2024-10-10 06:35:45,694 : INFO : 含 UNK 的前 20 个高频词[['UNK', 3415601], ('年', 1574104), ('中', 842526), ('后', 744954), ('日', 689411), ('小行星', 667006), ('人', 545308), ('月', 460288), ('上', 445179), ('时', 378960), ('不', 351334), ('日本', 346432), ('中国', 335412), ('美国', 323930), ('会', 320299), ('都', 304521), ('大', 295780), ('香港', 283194), ('号', 280674), ('站', 273673)]
# 2024-10-10 06:35:45,695 : INFO : 查看索引与词的映射：
# 2024-10-10 06:35:45,696 : INFO : 29486 : 欧几里得, 12266 : 西元前, 255 : 三, 119 : 世纪, 6762 : 古希腊, 4811 : 数学家, 331 : 现在, 77 : 认为, 6232 : 几何, 3301 : 父,
# 2024-10-10 06:36:00,318 : INFO : 初始化完成...
# 2024-10-10 06:36:00,646 : INFO : 在第 0 次循环的平均损失为: 381.124969
# 2024-10-10 06:36:00,647 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:36:02,667 : INFO : 单词 父亲 的最相似的 10 个单词为： 卡拉格, 平群, 溥煦, 醉象, 笔泉, 崔景嵩, 守恒, 扈再兴, 小柯瑞, 腹肚,
# 2024-10-10 06:36:02,695 : INFO : 单词 中国 的最相似的 10 个单词为： 客整, 授乳, 八九个, 成住, 如渊, 田逸子, 袁运甫, 费解, 祖特梅尔, 丁洙,
# 2024-10-10 06:36:02,721 : INFO : 单词 电脑 的最相似的 10 个单词为： 磁悬浮列车, 草木, 李自成, 送站, 自沉于, 影印件, 王宇威, 干河, 露芝, 梁思韵,
# 2024-10-10 06:36:02,747 : INFO : 单词 手机 的最相似的 10 个单词为： 于仲民, 木车, 漌, 损伤, 来得早, 水坞, 茶余饭后, 春治, 碾村, 鼓皮,
# 2024-10-10 06:36:02,773 : INFO : 单词 书籍 的最相似的 10 个单词为： 苗易彬, 爱旭, 阳三郡, 饭里, 渺子, 效方, 郑美京, 尼是, 张树桢, 庆光,
# 2024-10-10 06:36:02,801 : INFO : 单词 公里 的最相似的 10 个单词为： 畅聊, 何瑞真, 依洛乡, 绕圈圈, 褚亮, 楚离, 其柱, 刘兆凯, 上里, 耶洗,
# 2024-10-10 06:36:02,830 : INFO : 单词 还 的最相似的 10 个单词为： 冈野佳, 陈慎公, 毕晓海, 朴惠, 披肩, 捷报, 中胜选, 大现, 巨臂, 彭锷,
# 2024-10-10 06:36:02,859 : INFO : 单词 部分 的最相似的 10 个单词为： 岚忠, 赫南, 郑俊浩, 虽勤, 行财处, 常府, 存中, 治临, 木赁, 陈火庆,
# 2024-10-10 06:36:02,887 : INFO : 单词 年 的最相似的 10 个单词为： 无轴, 油业, 地车, 正, 梦道, 妻命, 任蔓琳, 麦趣, 周耀明, 其神名,
# 2024-10-10 06:36:02,914 : INFO : 单词 之后 的最相似的 10 个单词为： 节里, 南六环, 龙床, 科布伦茨, 北冲, 卞宇珉, 足盟, 旗中, 韩颓, 伯高,
# 2024-10-10 06:36:09,532 : INFO : 在第 2000 次循环的平均损失为: 266.220614
# 2024-10-10 06:36:16,122 : INFO : 在第 4000 次循环的平均损失为: 213.489264
# 2024-10-10 06:36:22,792 : INFO : 在第 6000 次循环的平均损失为: 189.224152
# 2024-10-10 06:36:29,498 : INFO : 在第 8000 次循环的平均损失为: 171.737992
# 2024-10-10 06:36:36,109 : INFO : 在第 10000 次循环的平均损失为: 161.249943
# 2024-10-10 06:36:36,110 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:36:38,154 : INFO : 单词 父亲 的最相似的 10 个单词为： 守恒, 单于庭, 沙普利, 林下, 博茨瓦纳, 普格县, 性平会, 非零, 治体, 杀俘,
# 2024-10-10 06:36:38,182 : INFO : 单词 中国 的最相似的 10 个单词为： 年, 中, 靖虏, 精炼, 之群, 大陆, 后, 虚, 主要, 小数点,
# 2024-10-10 06:36:38,209 : INFO : 单词 电脑 的最相似的 10 个单词为： 导向, 珠江口, 宏村, 李自成, 登报, 被元廷, 旗下, 奶酪, 凌云县, 功利性,
# 2024-10-10 06:36:38,235 : INFO : 单词 手机 的最相似的 10 个单词为： 白子, 非常容易, 信息科学, 于攻, 湖内, 傈僳族, 张敬达, 战略地位, 发明者, 刘继元,
# 2024-10-10 06:36:38,260 : INFO : 单词 书籍 的最相似的 10 个单词为： 该软件, 喷发, 解译, 琼海市, 守河, 丹阳市, 夔龙, 孔子, 裔, 两百,
# 2024-10-10 06:36:38,286 : INFO : 单词 公里 的最相似的 10 个单词为： 约, 英果, 一山, 美国, 孔祥熙, 泉源, 南无, 易使用, 同前, 磐,
# 2024-10-10 06:36:38,312 : INFO : 单词 还 的最相似的 10 个单词为： 包括, 成为, 年, 后, 四川长虹, 歴, 时, 战线, 发展, 龙云里,
# 2024-10-10 06:36:38,337 : INFO : 单词 部分 的最相似的 10 个单词为： 模组化, 重大案件, 上, 琜, 粮米, 佩利, 东胜, 随处可见, 林炜, 香水,
# 2024-10-10 06:36:38,362 : INFO : 单词 年 的最相似的 10 个单词为： 后, 中, 成为, 时, 上, 台湾, 建立, 中国, 都, UNK,
# 2024-10-10 06:36:38,387 : INFO : 单词 之后 的最相似的 10 个单词为： 诊治, 不, 年, 王审知, 美心, 衡山, 都, 计划单列, 路过, 龙潭,
# 2024-10-10 06:36:45,020 : INFO : 在第 12000 次循环的平均损失为: 144.867667
# 2024-10-10 06:36:51,590 : INFO : 在第 14000 次循环的平均损失为: 137.311960
# 2024-10-10 06:36:58,261 : INFO : 在第 16000 次循环的平均损失为: 131.429353
# 2024-10-10 06:37:04,887 : INFO : 在第 18000 次循环的平均损失为: 125.978643
# 2024-10-10 06:37:11,479 : INFO : 在第 20000 次循环的平均损失为: 120.045163
# 2024-10-10 06:37:11,480 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:37:13,506 : INFO : 单词 父亲 的最相似的 10 个单词为： 性平会, 帕凡舞, 杀俘, 正式, 厅名, 乔纳斯, 钱氏, 端拱, 绝嗣, 安居,
# 2024-10-10 06:37:13,533 : INFO : 单词 中国 的最相似的 10 个单词为： 中, 上, 年, 时期, 台湾, 后, 政治, UNK, 亦, 研究,
# 2024-10-10 06:37:13,559 : INFO : 单词 电脑 的最相似的 10 个单词为： 战地, 导向, 妄行, 信息时报, 海协会, 病句, 本于, 陈部, 磁悬浮列车, 贝利,
# 2024-10-10 06:37:13,585 : INFO : 单词 手机 的最相似的 10 个单词为： 欺侮, 雷根, 秘史, 非常容易, 选用, 火曜日, 卡德, 张敬达, 李大夫, 阿马,
# 2024-10-10 06:37:13,610 : INFO : 单词 书籍 的最相似的 10 个单词为： 该软件, 右卫, 仙后座, 琼海市, 丹阳市, 李国鼎, 守河, 不会, 夔龙, 孔子,
# 2024-10-10 06:37:13,636 : INFO : 单词 公里 的最相似的 10 个单词为： 反扁, 二十六, 翻坝, 平顺, 津秦, 耐磨, 大理岩, 克卜勒, 约, 下层社会,
# 2024-10-10 06:37:13,661 : INFO : 单词 还 的最相似的 10 个单词为： 都, 中, 建立, 蔡林格, 称为, 上, 研究, 国家, 社宅, 不,
# 2024-10-10 06:37:13,687 : INFO : 单词 部分 的最相似的 10 个单词为： 都, 年, 马面, 中, 没有, 世界, 大, 奥里亚, 共有, 仁皇,
# 2024-10-10 06:37:13,712 : INFO : 单词 年 的最相似的 10 个单词为： 美国, 后, 中, 英国, 政治, 上, 台湾, 中国, 出生, 法国,
# 2024-10-10 06:37:13,737 : INFO : 单词 之后 的最相似的 10 个单词为： 国家, UNK, 为君, 一种, 都, 完成学业, 张之亮, 内, 错流, 布衣知县,
# 2024-10-10 06:37:20,353 : INFO : 在第 22000 次循环的平均损失为: 113.270946
# 2024-10-10 06:37:26,718 : INFO : 在第 24000 次循环的平均损失为: 106.247713
# 2024-10-10 06:37:33,316 : INFO : 在第 26000 次循环的平均损失为: 107.725794
# 2024-10-10 06:37:39,884 : INFO : 在第 28000 次循环的平均损失为: 101.792715
# 2024-10-10 06:37:46,505 : INFO : 在第 30000 次循环的平均损失为: 95.556475
# 2024-10-10 06:37:46,507 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:37:48,527 : INFO : 单词 父亲 的最相似的 10 个单词为： 汽油味, 奉养, 入监, 春王, 天资, 时尊, 性平会, 管理科学, 八连, 黄公,
# 2024-10-10 06:37:48,553 : INFO : 单词 中国 的最相似的 10 个单词为： 年, 后, 台湾, 世界, 英国, 美国, 上, 中华人民共和国, 中, 日本,
# 2024-10-10 06:37:48,582 : INFO : 单词 电脑 的最相似的 10 个单词为： 耐碱, 作业系统, 内, 地区, 涅涅茨, 执行, 方法, 吹打, 皮草, 战地,
# 2024-10-10 06:37:48,607 : INFO : 单词 手机 的最相似的 10 个单词为： 欺侮, 热身赛, 阿马, 火曜日, 见宁, 雷根, 照常, 战略地位, 奢求, 选用,
# 2024-10-10 06:37:48,632 : INFO : 单词 书籍 的最相似的 10 个单词为： 阳三郡, 类似, 该软件, 仙后座, 不会, 孔子, 已至, 约翰, 很快, 罗琳,
# 2024-10-10 06:37:48,658 : INFO : 单词 公里 的最相似的 10 个单词为： 蛤仔, 指挥机构, 长, 车用汽油, 安井算知, 一邻, 防城港市, 阿古, 罪魁祸首, 大桥,
# 2024-10-10 06:37:48,683 : INFO : 单词 还 的最相似的 10 个单词为： 中国, 皆, 后, 使, 中, 时, 当时, 没有, 月, 都,
# 2024-10-10 06:37:48,708 : INFO : 单词 部分 的最相似的 10 个单词为： 新, 上, 地区, 后, 中, 目前, 最终, 德国, 历史, 会,
# 2024-10-10 06:37:48,733 : INFO : 单词 年 的最相似的 10 个单词为： 后, 英国, 美国, 中, 中国, 大, 包括, 成为, 成立, 当时,
# 2024-10-10 06:37:48,758 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 中, 成为, 新, 年, 皆, 不, 月, 发生, 当时,
# 2024-10-10 06:37:55,394 : INFO : 在第 32000 次循环的平均损失为: 91.609679
# 2024-10-10 06:38:01,854 : INFO : 在第 34000 次循环的平均损失为: 91.725964
# 2024-10-10 06:38:08,432 : INFO : 在第 36000 次循环的平均损失为: 88.021795
# 2024-10-10 06:38:15,136 : INFO : 在第 38000 次循环的平均损失为: 85.485202
# 2024-10-10 06:38:21,958 : INFO : 在第 40000 次循环的平均损失为: 81.794570
# 2024-10-10 06:38:21,960 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:38:23,997 : INFO : 单词 父亲 的最相似的 10 个单词为： 时, 初, UNK, 为布, 卡尔松, 伤神, 曾, 商家, 可能, 港为,
# 2024-10-10 06:38:24,023 : INFO : 单词 中国 的最相似的 10 个单词为： 美国, 台湾, 年, 日本, 上, 香港, 都, 英国, 正式, UNK,
# 2024-10-10 06:38:24,048 : INFO : 单词 电脑 的最相似的 10 个单词为： 天命之誓, 思立, 耐碱, 向法军, 农家乐, 阴谋论, 窦唯, 吹打, 恩格, 柏树,
# 2024-10-10 06:38:24,074 : INFO : 单词 手机 的最相似的 10 个单词为： 雷根, 热身赛, 导, 超级女, 奢求, 阿马, 火曜日, 战略地位, 欺侮, 小堂,
# 2024-10-10 06:38:24,101 : INFO : 单词 书籍 的最相似的 10 个单词为： 该软件, 已至, 阳三郡, 阿蓝, 直街, 仙后座, 传播学院, 西亳, 马尔达, 背包,
# 2024-10-10 06:38:24,126 : INFO : 单词 公里 的最相似的 10 个单词为： 约, 两厢, 南北, 奥尔德, 距离, 达, 形成, 唐明, 播放机, 现在,
# 2024-10-10 06:38:24,152 : INFO : 单词 还 的最相似的 10 个单词为： 中, 称, 没有, 使, 曾, 外, 使用, 上, 包括, 大,
# 2024-10-10 06:38:24,177 : INFO : 单词 部分 的最相似的 10 个单词为： 上, 历史, 新, 中, 成功, 今, 分别, 最, 仅, 地区,
# 2024-10-10 06:38:24,203 : INFO : 单词 年 的最相似的 10 个单词为： 美国, 逝世, 英国, 出生, 中国, 法国, 日本, 台湾, 德国, 香港,
# 2024-10-10 06:38:24,228 : INFO : 单词 之后 的最相似的 10 个单词为： 时, 中, 年, 年代, 上, 成为, 日, 后, 包括, UNK,
# 2024-10-10 06:38:30,555 : INFO : 在第 42000 次循环的平均损失为: 79.061817
# 2024-10-10 06:38:37,165 : INFO : 在第 44000 次循环的平均损失为: 74.037174
# 2024-10-10 06:38:43,768 : INFO : 在第 46000 次循环的平均损失为: 74.993969
# 2024-10-10 06:38:50,352 : INFO : 在第 48000 次循环的平均损失为: 73.664538
# 2024-10-10 06:38:56,967 : INFO : 在第 50000 次循环的平均损失为: 73.437059
# 2024-10-10 06:38:56,969 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:38:59,006 : INFO : 单词 父亲 的最相似的 10 个单词为： 中, 成为, 都, UNK, 可能, 美国, 使, 军队, 烈爱, 曾,
# 2024-10-10 06:38:59,034 : INFO : 单词 中国 的最相似的 10 个单词为： 美国, 年, 日本, 台湾, 日, 女演员, 演员, 法国, 关系, 人,
# 2024-10-10 06:38:59,060 : INFO : 单词 电脑 的最相似的 10 个单词为： 可能, 阴谋论, 改变, 更, 天命之誓, 执行, 思立, 使用, 港脚, 系统,
# 2024-10-10 06:38:59,086 : INFO : 单词 手机 的最相似的 10 个单词为： 热身赛, 来自, 常磨, 导, 超级女, 战略地位, 火曜日, 阿马, 退辅会, 载客,
# 2024-10-10 06:38:59,112 : INFO : 单词 书籍 的最相似的 10 个单词为： 每天, 记载, 做, 阳三郡, 后来, 基础, 更, 该软件, 阿蓝, 支持,
# 2024-10-10 06:38:59,137 : INFO : 单词 公里 的最相似的 10 个单词为： 约, 长, 达, 位于, 北部, 时间, 以下, 地区, 铁路, 城市,
# 2024-10-10 06:38:59,164 : INFO : 单词 还 的最相似的 10 个单词为： 中, 月, 上, 可能, 荥, 认为, 年, 问题, 局长, 仍,
# 2024-10-10 06:38:59,189 : INFO : 单词 部分 的最相似的 10 个单词为： 新, 使用, 中, 包括, 没有, 可能, 均, 变化, 区, 上,
# 2024-10-10 06:38:59,214 : INFO : 单词 年 的最相似的 10 个单词为： 美国, 逝世, 中, 英国, 后, 法国, 月, 德国, 成为, 政治,
# 2024-10-10 06:38:59,240 : INFO : 单词 之后 的最相似的 10 个单词为： 年, 最后, 中, 年代, 月, 成为, 人, 时期, 期间, 支持,
# 2024-10-10 06:39:05,791 : INFO : 在第 52000 次循环的平均损失为: 67.897233
# 2024-10-10 06:39:12,353 : INFO : 在第 54000 次循环的平均损失为: 66.584574
# 2024-10-10 06:39:18,975 : INFO : 在第 56000 次循环的平均损失为: 67.365841
# 2024-10-10 06:39:25,358 : INFO : 在第 58000 次循环的平均损失为: 64.516732
# 2024-10-10 06:39:31,448 : INFO : 在第 60000 次循环的平均损失为: 64.971856
# 2024-10-10 06:39:31,449 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:39:33,459 : INFO : 单词 父亲 的最相似的 10 个单词为： 后, 年, 时, 来自, 英国, 母亲, 工作, 查尔斯, 去世, 王朝,
# 2024-10-10 06:39:33,484 : INFO : 单词 中国 的最相似的 10 个单词为： 台湾, 美国, 香港, 年, 国家, 目前, 英国, 历史, 主要, 研究,
# 2024-10-10 06:39:33,510 : INFO : 单词 电脑 的最相似的 10 个单词为： 可能, 包括, 系统, 动物, 分为, 发展, 阴谋论, 圣安纳, 通常, 达仁,
# 2024-10-10 06:39:33,534 : INFO : 单词 手机 的最相似的 10 个单词为： 超级女, 热身赛, 保护, 董扶, 奢求, 常磨, 战略地位, 雷根, 火曜日, 拒于,
# 2024-10-10 06:39:33,559 : INFO : 单词 书籍 的最相似的 10 个单词为： 基础, 刘煕, 更, 角度, 仙后座, 外, 薛王, 包机, 阳三郡, 日版,
# 2024-10-10 06:39:33,583 : INFO : 单词 公里 的最相似的 10 个单词为： 提供, 智喜, 尚史, 王进逵, 另选, 冲日, 王园, 石类, 奇洛, 郭顺仪,
# 2024-10-10 06:39:33,608 : INFO : 单词 还 的最相似的 10 个单词为： 不, 没有, 时, 都, 上, 当时, 使用, 人, 会, 包括,
# 2024-10-10 06:39:33,632 : INFO : 单词 部分 的最相似的 10 个单词为： 最, 不, 上, 分为, 都, 不同, 国家, 新, 要求, 以来,
# 2024-10-10 06:39:33,656 : INFO : 单词 年 的最相似的 10 个单词为： 美国, 后, 月, 不, 英国, 都, 出生, 逝世, 政治, 中,
# 2024-10-10 06:39:33,680 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 年, 不, 时, 都, 上, 建立, 包括, 时期, 英国,
# 2024-10-10 06:39:40,230 : INFO : 在第 62000 次循环的平均损失为: 59.627166
# 2024-10-10 06:39:46,786 : INFO : 在第 64000 次循环的平均损失为: 60.185109
# 2024-10-10 06:39:53,459 : INFO : 在第 66000 次循环的平均损失为: 56.334123
# 2024-10-10 06:39:59,963 : INFO : 在第 68000 次循环的平均损失为: 55.017218
# 2024-10-10 06:40:06,619 : INFO : 在第 70000 次循环的平均损失为: 54.893502
# 2024-10-10 06:40:06,621 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:40:08,661 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, UNK, 时, 去世, 后, 王, 还, 年, 都, 后来,
# 2024-10-10 06:40:08,686 : INFO : 单词 中国 的最相似的 10 个单词为： 年, 台湾, 日本, 月, 主要, 大陆, 经济, 成立, 国家, 简称,
# 2024-10-10 06:40:08,711 : INFO : 单词 电脑 的最相似的 10 个单词为： 系统, 发明, 技术, 中, 年, 上, 公开, 出现, 可能, 现代,
# 2024-10-10 06:40:08,735 : INFO : 单词 手机 的最相似的 10 个单词为： 热身赛, 没有, 董扶, 超级女, 申惠晶, 辛睿恩, 街, 少焉, 火曜日, 欺侮,
# 2024-10-10 06:40:08,760 : INFO : 单词 书籍 的最相似的 10 个单词为： 基础, UNK, 刘煕, 形式, 著作, 当时, 父母, 荡氏, 记载, 注重,
# 2024-10-10 06:40:08,784 : INFO : 单词 公里 的最相似的 10 个单词为： 约, 主要, 区, 米, 超过, 分别, 使用, 铁路, 内, 最大,
# 2024-10-10 06:40:08,809 : INFO : 单词 还 的最相似的 10 个单词为： 后, 上, 没有, 年, 人, 时, 曾, 不, 亦, 之后,
# 2024-10-10 06:40:08,833 : INFO : 单词 部分 的最相似的 10 个单词为： 上, 主要, 年, 要求, 内, 还, 中, 亦, 不同, 月,
# 2024-10-10 06:40:08,857 : INFO : 单词 年 的最相似的 10 个单词为： 后, 中, 英国, 中国, 美国, 前, 月, 上, 时, 包括,
# 2024-10-10 06:40:08,882 : INFO : 单词 之后 的最相似的 10 个单词为： 年, 后, 中, 日, 上, 没有, 出现, 直到, 这一, 都,
# 2024-10-10 06:40:15,375 : INFO : 在第 72000 次循环的平均损失为: 55.023820
# 2024-10-10 06:40:21,983 : INFO : 在第 74000 次循环的平均损失为: 56.789606
# 2024-10-10 06:40:28,690 : INFO : 在第 76000 次循环的平均损失为: 51.849286
# 2024-10-10 06:40:35,293 : INFO : 在第 78000 次循环的平均损失为: 50.011637
# 2024-10-10 06:40:41,863 : INFO : 在第 80000 次循环的平均损失为: 49.708571
# 2024-10-10 06:40:41,864 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:40:43,921 : INFO : 单词 父亲 的最相似的 10 个单词为： UNK, 后, 年, 母亲, 前, 不, 时, 曾, 都, 去世,
# 2024-10-10 06:40:43,946 : INFO : 单词 中国 的最相似的 10 个单词为： 年, 日本, 台湾, 美国, 香港, 前, 人, 英国, 合作, 政治,
# 2024-10-10 06:40:43,970 : INFO : 单词 电脑 的最相似的 10 个单词为： 两个, 系统, 都, 早期, 利用, 方法, 技术, 出现, 没有, 执行,
# 2024-10-10 06:40:43,996 : INFO : 单词 手机 的最相似的 10 个单词为： 现代, 热身赛, 超级女, 董扶, 全息, UNK, 保护, 发展, 中世纪, 管理,
# 2024-10-10 06:40:44,020 : INFO : 单词 书籍 的最相似的 10 个单词为： 基础, 一种, 已, 思想, 很多, 宗教, 上, 知道, 刘煕, 文化,
# 2024-10-10 06:40:44,045 : INFO : 单词 公里 的最相似的 10 个单词为： 铁路, 约, 大约, 地区, 面积, 达, 位于, 分为, 形成, 分别,
# 2024-10-10 06:40:44,069 : INFO : 单词 还 的最相似的 10 个单词为： 时, 都, 上, 后, 中, 前, 年, 没有, UNK, 下,
# 2024-10-10 06:40:44,095 : INFO : 单词 部分 的最相似的 10 个单词为： 内, 主要, 上, 下, 出现, 中, 出, 都, 后, 亦,
# 2024-10-10 06:40:44,119 : INFO : 单词 年 的最相似的 10 个单词为： 中国, 美国, 出生, 日本, 英国, 法国, 后, 前, 逝世, 作家,
# 2024-10-10 06:40:44,143 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 中, 都, 日, 下, 月, 还, 人, 后来, 已,
# 2024-10-10 06:40:50,766 : INFO : 在第 82000 次循环的平均损失为: 46.640603
# 2024-10-10 06:40:57,410 : INFO : 在第 84000 次循环的平均损失为: 46.927639
# 2024-10-10 06:41:04,044 : INFO : 在第 86000 次循环的平均损失为: 44.766635
# 2024-10-10 06:41:10,723 : INFO : 在第 88000 次循环的平均损失为: 47.796256
# 2024-10-10 06:41:17,398 : INFO : 在第 90000 次循环的平均损失为: 43.011897
# 2024-10-10 06:41:17,399 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:41:19,412 : INFO : 单词 父亲 的最相似的 10 个单词为： 都, 母亲, UNK, 后, 人, 期间, 不, 说, 曾, 最后,
# 2024-10-10 06:41:19,437 : INFO : 单词 中国 的最相似的 10 个单词为： 亚洲, 年, 皇帝, 后, 日本, 唐朝, 前, 领袖, UNK, 台湾,
# 2024-10-10 06:41:19,462 : INFO : 单词 电脑 的最相似的 10 个单词为： 系统, 之前, 利用, 方法, 没有, 目前, 这种, 两个, 才, 包含,
# 2024-10-10 06:41:19,487 : INFO : 单词 手机 的最相似的 10 个单词为： 现代, 南庵, 热身赛, 超级女, 保护, 正式, 雷根, 全息, 圣母, 董扶,
# 2024-10-10 06:41:19,512 : INFO : 单词 书籍 的最相似的 10 个单词为： 很快, 计算, 成立, 已, 思想, 之后, 这是, 刘煕, 这种, 情况,
# 2024-10-10 06:41:19,536 : INFO : 单词 公里 的最相似的 10 个单词为： 距离, 面积, 市区, 目前, 高, 境内, 东西, 位于, 主要, 城市,
# 2024-10-10 06:41:19,561 : INFO : 单词 还 的最相似的 10 个单词为： 没有, 不, 后, 时, 出现, 都, 之后, 上, 认为, 人,
# 2024-10-10 06:41:19,586 : INFO : 单词 部分 的最相似的 10 个单词为： UNK, 新, 包括, 需要, 内, 都, 中, 包含, 所有, 全部,
# 2024-10-10 06:41:19,610 : INFO : 单词 年 的最相似的 10 个单词为： 英国, 出生, 逝世, 美国, 日本, 后, UNK, 曾, 中, 法国,
# 2024-10-10 06:41:19,635 : INFO : 单词 之后 的最相似的 10 个单词为： 时, UNK, 月, 没有, 后, 日, 中, 人, 还, 认为,
# 2024-10-10 06:41:26,030 : INFO : 在第 92000 次循环的平均损失为: 46.392803
# 2024-10-10 06:41:32,631 : INFO : 在第 94000 次循环的平均损失为: 45.389272
# 2024-10-10 06:41:39,190 : INFO : 在第 96000 次循环的平均损失为: 43.158033
# 2024-10-10 06:41:45,845 : INFO : 在第 98000 次循环的平均损失为: 41.103881
# 2024-10-10 06:41:52,391 : INFO : 在第 100000 次循环的平均损失为: 42.126692
# 2024-10-10 06:41:52,392 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:41:54,493 : INFO : 单词 父亲 的最相似的 10 个单词为： 年, 母亲, 上, UNK, 人, 都, 曾, 不, 说, 后,
# 2024-10-10 06:41:54,521 : INFO : 单词 中国 的最相似的 10 个单词为： 台湾, 年, 日本, 美国, 前, 国家, 著名, 历史, 政治, 英国,
# 2024-10-10 06:41:54,546 : INFO : 单词 电脑 的最相似的 10 个单词为： 两个, 系统, 出现, 领域, 上, 再, 标准, 透过, 称为, 方法,
# 2024-10-10 06:41:54,571 : INFO : 单词 手机 的最相似的 10 个单词为： 称为, 保护, 南庵, 超级女, 热身赛, 技术, 取得, 画坊, 执行, 董扶,
# 2024-10-10 06:41:54,596 : INFO : 单词 书籍 的最相似的 10 个单词为： 时, 影响, 已, 知道, 部分, 分为, 这是, 基础, 上, 环境,
# 2024-10-10 06:41:54,620 : INFO : 单词 公里 的最相似的 10 个单词为： 城市, 主要, 距离, 地理, 约, 道路, 达, 高, 大型, 境内,
# 2024-10-10 06:41:54,645 : INFO : 单词 还 的最相似的 10 个单词为： 都, 没有, 更, 当时, 时, 后, UNK, 去, 认为, 年,
# 2024-10-10 06:41:54,670 : INFO : 单词 部分 的最相似的 10 个单词为： 上, 包括, 主要, 都, 所有, 不, 国家, 年, 中, 需要,
# 2024-10-10 06:41:54,695 : INFO : 单词 年 的最相似的 10 个单词为： 美国, 出生, 英国, 逝世, 后, 前, 成为, 中, 中国, 法国,
# 2024-10-10 06:41:54,720 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 时, 受到, 都, 日, 已经, 没有, 进行, 成为, 上,
# 2024-10-10 06:42:01,352 : INFO : 在第 102000 次循环的平均损失为: 41.375232
# 2024-10-10 06:42:08,059 : INFO : 在第 104000 次循环的平均损失为: 39.108442
# 2024-10-10 06:42:14,504 : INFO : 在第 106000 次循环的平均损失为: 41.833821
# 2024-10-10 06:42:21,045 : INFO : 在第 108000 次循环的平均损失为: 37.649546
# 2024-10-10 06:42:27,632 : INFO : 在第 110000 次循环的平均损失为: 36.505650
# 2024-10-10 06:42:27,633 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:42:29,674 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 年, 一位, 曾, UNK, 后来, 这是, 成为, 女儿, 时,
# 2024-10-10 06:42:29,700 : INFO : 单词 中国 的最相似的 10 个单词为： 文化, 年, 台湾, 历史, 艺术, 大陆, 香港, 国际, 曾, 最早,
# 2024-10-10 06:42:29,725 : INFO : 单词 电脑 的最相似的 10 个单词为： 早期, 具有, 技术, 类似, 历史, 标准, 系统, 更, 发展, 包括,
# 2024-10-10 06:42:29,750 : INFO : 单词 手机 的最相似的 10 个单词为： 技术, 南庵, 热身赛, 新, 已经, 保护, 超级女, 董扶, 第一, 内容,
# 2024-10-10 06:42:29,774 : INFO : 单词 书籍 的最相似的 10 个单词为： 概念, 认为, 部分, 很快, 出现, 张, 计算, 社会, 选择, 已经,
# 2024-10-10 06:42:29,799 : INFO : 单词 公里 的最相似的 10 个单词为： 城市, 米, 约, 小, 达, 高, 最大, 面积, 公路, 宽,
# 2024-10-10 06:42:29,824 : INFO : 单词 还 的最相似的 10 个单词为： 中, 上, 大, 没有, 情况, 包括, 年, 使, 不, UNK,
# 2024-10-10 06:42:29,851 : INFO : 单词 部分 的最相似的 10 个单词为： 年, 上, 进行, 所有, 包括, 大, 重要, 中, 主要, 目前,
# 2024-10-10 06:42:29,876 : INFO : 单词 年 的最相似的 10 个单词为： 美国, 后, 英国, 中, 台湾, 日, 月, 成为, 法国, 正式,
# 2024-10-10 06:42:29,901 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 时, 中, 年, 仍, 曾, 下, 成为, 没有, 日,
# 2024-10-10 06:42:36,481 : INFO : 在第 112000 次循环的平均损失为: 37.694968
# 2024-10-10 06:42:42,949 : INFO : 在第 114000 次循环的平均损失为: 37.221653
# 2024-10-10 06:42:49,302 : INFO : 在第 116000 次循环的平均损失为: 37.501698
# 2024-10-10 06:42:55,610 : INFO : 在第 118000 次循环的平均损失为: 35.167639
# 2024-10-10 06:43:02,163 : INFO : 在第 120000 次循环的平均损失为: 34.346302
# 2024-10-10 06:43:02,164 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:43:04,188 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 后来, 时, 曾, 成为, UNK, 后, 去世, 人, 年,
# 2024-10-10 06:43:04,213 : INFO : 单词 中国 的最相似的 10 个单词为： 年, 大陆, 日本, 香港, 著名, 包括, 后, 日, 台湾, 文化,
# 2024-10-10 06:43:04,238 : INFO : 单词 电脑 的最相似的 10 个单词为： 技术, 具有, 标准, 都, 早期, 更, 间, 上, 利用, 一种,
# 2024-10-10 06:43:04,262 : INFO : 单词 手机 的最相似的 10 个单词为： 技术, 内容, 不是, 南庵, 差异, 鹤洞, 董扶, 类似, 热身赛, 运行,
# 2024-10-10 06:43:04,286 : INFO : 单词 书籍 的最相似的 10 个单词为： 很多, 概念, 张, 作品, 文化, 都, 不, 历史, 年, 上,
# 2024-10-10 06:43:04,310 : INFO : 单词 公里 的最相似的 10 个单词为： 城市, 主要, 约, 小, 最大, 内, 地区, 东部, 成, 宽,
# 2024-10-10 06:43:04,333 : INFO : 单词 还 的最相似的 10 个单词为： 时, 年, 中, 不, 都, 上, 后, 人, 认为, 很,
# 2024-10-10 06:43:04,357 : INFO : 单词 部分 的最相似的 10 个单词为： 国家, 都, 所有, 人, 后, 大部分, UNK, 发展, 年, 各地,
# 2024-10-10 06:43:04,381 : INFO : 单词 年 的最相似的 10 个单词为： 后, 中国, 日, 前, 中, 英国, 月, 成为, 首次, 美国,
# 2024-10-10 06:43:04,404 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 年, 当时, 日, 却, 成为, 时, 才, 前, 中,
# 2024-10-10 06:43:11,033 : INFO : 在第 122000 次循环的平均损失为: 32.992276
# 2024-10-10 06:43:17,618 : INFO : 在第 124000 次循环的平均损失为: 35.336139
# 2024-10-10 06:43:24,379 : INFO : 在第 126000 次循环的平均损失为: 33.877288
# 2024-10-10 06:43:30,974 : INFO : 在第 128000 次循环的平均损失为: 33.489565
# 2024-10-10 06:43:37,608 : INFO : 在第 130000 次循环的平均损失为: 32.243332
# 2024-10-10 06:43:37,609 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:43:39,634 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 曾, UNK, 儿子, 去世, 都, 后来, 人, 岁, 约翰,
# 2024-10-10 06:43:39,659 : INFO : 单词 中国 的最相似的 10 个单词为： 年, 大陆, 美国, 台湾, 文化, 日本, 成为, 香港, 曾, 大学,
# 2024-10-10 06:43:39,684 : INFO : 单词 电脑 的最相似的 10 个单词为： 技术, 系统, 计算机, 科学, 分析, 电子, 早期, 应用, 取代, 使用,
# 2024-10-10 06:43:39,708 : INFO : 单词 手机 的最相似的 10 个单词为： 第一个, 超级女, 技术, 核心, 基础, 内容, 特殊, 建立, 已经, 之坑,
# 2024-10-10 06:43:39,734 : INFO : 单词 书籍 的最相似的 10 个单词为： 自由, 成为, UNK, 主要, 概念, 文化, 经常, 影响, 中, 上,
# 2024-10-10 06:43:39,758 : INFO : 单词 公里 的最相似的 10 个单词为： 约, 城市, 境内, 位于, 达, 西北, 最大, 大约, 主要, 东南,
# 2024-10-10 06:43:39,783 : INFO : 单词 还 的最相似的 10 个单词为： 上, 包括, 都, 后来, 之后, 没有, 时, 会, 里, UNK,
# 2024-10-10 06:43:39,807 : INFO : 单词 部分 的最相似的 10 个单词为： 上, 包括, 后, 中, 年, 大, 成为, 发展, 成立, 当时,
# 2024-10-10 06:43:39,831 : INFO : 单词 年 的最相似的 10 个单词为： 后, 月, 美国, 成为, 中国, 日, 成立, 英国, 曾, 香港,
# 2024-10-10 06:43:39,855 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 成为, 年, 日, 最后, 却, 期间, 时, 当时, UNK,
# 2024-10-10 06:43:46,332 : INFO : 在第 132000 次循环的平均损失为: 30.533705
# 2024-10-10 06:43:52,907 : INFO : 在第 134000 次循环的平均损失为: 31.959712
# 2024-10-10 06:43:59,489 : INFO : 在第 136000 次循环的平均损失为: 35.466836
# 2024-10-10 06:44:05,835 : INFO : 在第 138000 次循环的平均损失为: 29.907691
# 2024-10-10 06:44:12,279 : INFO : 在第 140000 次循环的平均损失为: 33.131758
# 2024-10-10 06:44:12,280 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:44:14,324 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, UNK, 儿子, 人, 家庭, 曾, 去世, 说, 死, 作家,
# 2024-10-10 06:44:14,349 : INFO : 单词 中国 的最相似的 10 个单词为： 台湾, 年, 大陆, 日本, 成为, 历史, 美国, 香港, 曾, 大学,
# 2024-10-10 06:44:14,373 : INFO : 单词 电脑 的最相似的 10 个单词为： 系统, 管理, 包括, 取代, 分析, 提供, 技术, 计算机, 开发, 电子,
# 2024-10-10 06:44:14,397 : INFO : 单词 手机 的最相似的 10 个单词为： 基础, 开发, 包括, 产品, 几乎, 建立, 标准, 世界, 大多数, 制造,
# 2024-10-10 06:44:14,421 : INFO : 单词 书籍 的最相似的 10 个单词为： 经常, 上, 重要, 生活, 主要, 亦, 代表, 还, 中国, 目前,
# 2024-10-10 06:44:14,445 : INFO : 单词 公里 的最相似的 10 个单词为： 米, 境内, 南, 部分, 约, 内, 条, 建成, 现今, 城市,
# 2024-10-10 06:44:14,469 : INFO : 单词 还 的最相似的 10 个单词为： 后, 包括, 年, 当时, 人, 不, 没有, 亦, 大, UNK,
# 2024-10-10 06:44:14,493 : INFO : 单词 部分 的最相似的 10 个单词为： 包括, 之间, 上, 组成, 后, 地区, 主要, 中, 内, 里,
# 2024-10-10 06:44:14,516 : INFO : 单词 年 的最相似的 10 个单词为： 美国, 成为, 后, 英国, 曾, 日, 中国, 成立, 大学, 期间,
# 2024-10-10 06:44:14,541 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 年, 期间, 后来, 中国, 里, 上, 曾, 中, 时,
# 2024-10-10 06:44:21,032 : INFO : 在第 142000 次循环的平均损失为: 27.950222
# 2024-10-10 06:44:27,562 : INFO : 在第 144000 次循环的平均损失为: 29.782967
# 2024-10-10 06:44:34,128 : INFO : 在第 146000 次循环的平均损失为: 29.392714
# 2024-10-10 06:44:40,686 : INFO : 在第 148000 次循环的平均损失为: 30.116574
# 2024-10-10 06:44:47,092 : INFO : 在第 150000 次循环的平均损失为: 28.060436
# 2024-10-10 06:44:47,093 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:44:49,171 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 儿子, UNK, 时, 一位, 家庭, 里, 不, 说, 人,
# 2024-10-10 06:44:49,198 : INFO : 单词 中国 的最相似的 10 个单词为： 年, 大陆, 美国, 日本, 台湾, 香港, 前, 成为, 月, 中,
# 2024-10-10 06:44:49,226 : INFO : 单词 电脑 的最相似的 10 个单词为： 功能, 应用, 技术, 第一个, 游戏, 中, 电子, 研究, 设备, 使用,
# 2024-10-10 06:44:49,256 : INFO : 单词 手机 的最相似的 10 个单词为： 产品, 用于, 包括, 程式, 制造, 运行, 基础, 完成, 推出, 相对,
# 2024-10-10 06:44:49,286 : INFO : 单词 书籍 的最相似的 10 个单词为： 选择, 相关, 包括, 经常, 著作, 音乐, 指出, 投资, 艺术, 中国,
# 2024-10-10 06:44:49,316 : INFO : 单词 公里 的最相似的 10 个单词为： 约, 达, 东西, 境内, 南, 米, 城市, 面积, 长度, 大,
# 2024-10-10 06:44:49,343 : INFO : 单词 还 的最相似的 10 个单词为： 都, UNK, 不, 会, 中, 更, 没有, 下, 认为, 才,
# 2024-10-10 06:44:49,373 : INFO : 单词 部分 的最相似的 10 个单词为： 中, 大, UNK, 之间, 包括, 里, 主要, 地区, 均, 上,
# 2024-10-10 06:44:49,403 : INFO : 单词 年 的最相似的 10 个单词为： 美国, 中国, 后, 前, 日, 成为, 同年, 月, 期间, 英国,
# 2024-10-10 06:44:49,433 : INFO : 单词 之后 的最相似的 10 个单词为： 还, UNK, 当时, 年, 中, 才, 后, 便, 都, 仍,
# 2024-10-10 06:44:55,938 : INFO : 在第 152000 次循环的平均损失为: 28.474775
# 2024-10-10 06:45:02,449 : INFO : 在第 154000 次循环的平均损失为: 28.518252
# 2024-10-10 06:45:08,792 : INFO : 在第 156000 次循环的平均损失为: 26.140884
# 2024-10-10 06:45:15,403 : INFO : 在第 158000 次循环的平均损失为: 25.176930
# 2024-10-10 06:45:21,986 : INFO : 在第 160000 次循环的平均损失为: 27.591003
# 2024-10-10 06:45:21,988 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:45:24,003 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, UNK, 儿子, 回到, 家庭, 人, 后, 说, 曾, 时,
# 2024-10-10 06:45:24,028 : INFO : 单词 中国 的最相似的 10 个单词为： 年, 大陆, 成为, 台湾, 香港, 日本, 方面, 主要, 亦, 美国,
# 2024-10-10 06:45:24,052 : INFO : 单词 电脑 的最相似的 10 个单词为： 游戏, 应用, 公司, 基础, 设备, 开发, 产品, 功能, 使用, 技术,
# 2024-10-10 06:45:24,076 : INFO : 单词 手机 的最相似的 10 个单词为： 产品, 核心, 程式, 标准, 基础, 包括, 完成, 南庵, 分析, 显示,
# 2024-10-10 06:45:24,100 : INFO : 单词 书籍 的最相似的 10 个单词为： 经常, 出现, 著作, 人, 一部, 方式, 都, 指出, 已, 中,
# 2024-10-10 06:45:24,124 : INFO : 单词 公里 的最相似的 10 个单词为： 东西, 米, 约, 超过, 速度, 达, 长度, 条, 接近, 内,
# 2024-10-10 06:45:24,147 : INFO : 单词 还 的最相似的 10 个单词为： 不, 中, 包括, 都, 没有, 更, 内, 上, 人, 下,
# 2024-10-10 06:45:24,171 : INFO : 单词 部分 的最相似的 10 个单词为： 中, 均, 主要, 大, 都, 外, 还, 包括, 内, 通常,
# 2024-10-10 06:45:24,195 : INFO : 单词 年 的最相似的 10 个单词为： 美国, 英国, 前, 成为, 中国, 后, 月, 时, 中, 香港,
# 2024-10-10 06:45:24,220 : INFO : 单词 之后 的最相似的 10 个单词为： 年, 后, 当时, 时, 中, 便, 人, 才, 还, UNK,
# 2024-10-10 06:45:30,800 : INFO : 在第 162000 次循环的平均损失为: 27.264892
# 2024-10-10 06:45:37,178 : INFO : 在第 164000 次循环的平均损失为: 24.464665
# 2024-10-10 06:45:43,782 : INFO : 在第 166000 次循环的平均损失为: 25.004462
# 2024-10-10 06:45:50,359 : INFO : 在第 168000 次循环的平均损失为: 25.686951
# 2024-10-10 06:45:57,010 : INFO : 在第 170000 次循环的平均损失为: 25.250588
# 2024-10-10 06:45:57,011 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:45:59,063 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 家庭, 儿子, 生平, 一位, 后来, 时, 孩子, 后, 中,
# 2024-10-10 06:45:59,089 : INFO : 单词 中国 的最相似的 10 个单词为： 年, 英国, 上, 香港, 成为, 大陆, 日本, 台湾, 美国, 人,
# 2024-10-10 06:45:59,114 : INFO : 单词 电脑 的最相似的 10 个单词为： 应用, 游戏, 相关, 公司, 使用, 产品, 上, 核心, 技术, 开发,
# 2024-10-10 06:45:59,139 : INFO : 单词 手机 的最相似的 10 个单词为： 产品, 核心, 程式, 分析, 工程师, 开发, 数字, 南庵, 服务, 用于,
# 2024-10-10 06:45:59,163 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版, 作品, 年, 著作, 中, 成功, 包括, 指出, 新, 撰写,
# 2024-10-10 06:45:59,188 : INFO : 单词 公里 的最相似的 10 个单词为： 东西, 约, 达, 小时, 南, 最大, 位于, 市区, 处, 东南,
# 2024-10-10 06:45:59,212 : INFO : 单词 还 的最相似的 10 个单词为： 包括, 都, 中, 人, 时, 上, 之后, 部分, 当时, 没有,
# 2024-10-10 06:45:59,235 : INFO : 单词 部分 的最相似的 10 个单词为： 中, 上, 都, 外, 包括, 还, 主要, 时, 不同, 仍,
# 2024-10-10 06:45:59,259 : INFO : 单词 年 的最相似的 10 个单词为： 后, 日, 月, 前, 英国, 美国, 香港, 中, 获得, 之后,
# 2024-10-10 06:45:59,283 : INFO : 单词 之后 的最相似的 10 个单词为： 年, 后, 前, 才, 后来, 英国, 都, 随后, 还, 成为,
# 2024-10-10 06:46:05,900 : INFO : 在第 172000 次循环的平均损失为: 23.449342
# 2024-10-10 06:46:12,542 : INFO : 在第 174000 次循环的平均损失为: 24.276247
# 2024-10-10 06:46:19,166 : INFO : 在第 176000 次循环的平均损失为: 24.178481
# 2024-10-10 06:46:25,757 : INFO : 在第 178000 次循环的平均损失为: 24.320748
# 2024-10-10 06:46:32,288 : INFO : 在第 180000 次循环的平均损失为: 22.887924
# 2024-10-10 06:46:32,289 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:46:34,312 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, UNK, 儿子, 生平, 说, 后, 家庭, 后来, 出生, 还,
# 2024-10-10 06:46:34,336 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 台湾, 年, 日本, 国家, 香港, 英国, 文化, 成为, 曾,
# 2024-10-10 06:46:34,360 : INFO : 单词 电脑 的最相似的 10 个单词为： 技术, 内容, 游戏, 相关, 开发, 设计, 应用, 电子, 领域, 制作,
# 2024-10-10 06:46:34,384 : INFO : 单词 手机 的最相似的 10 个单词为： 产品, 包括, 核心, 网络, 上, 技术, 工程师, 服务, 程式, 开发,
# 2024-10-10 06:46:34,408 : INFO : 单词 书籍 的最相似的 10 个单词为： 台湾, 新, 年, 出版, 个人, 创作, 名称, 电影, 英文, 包括,
# 2024-10-10 06:46:34,432 : INFO : 单词 公里 的最相似的 10 个单词为： 约, 最大, 长度, 范围, 长, 达, 东西, 城市, 小时, 区域,
# 2024-10-10 06:46:34,455 : INFO : 单词 还 的最相似的 10 个单词为： 包括, 中, 都, 后, 成为, 没有, 上, 更, 曾, 之后,
# 2024-10-10 06:46:34,478 : INFO : 单词 部分 的最相似的 10 个单词为： 上, 包括, 中, 地区, 大部分, UNK, 没有, 目前, 都, 主要,
# 2024-10-10 06:46:34,502 : INFO : 单词 年 的最相似的 10 个单词为： 后, 月, 英国, 期间, 美国, 成为, 前, 曾, 首次, 中,
# 2024-10-10 06:46:34,526 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 年, 中, 当时, UNK, 时, 还, 成为, 期间, 才,
# 2024-10-10 06:46:40,795 : INFO : 在第 182000 次循环的平均损失为: 23.003310
# 2024-10-10 06:46:47,306 : INFO : 在第 184000 次循环的平均损失为: 23.023936
# 2024-10-10 06:46:53,609 : INFO : 在第 186000 次循环的平均损失为: 22.013032
# 2024-10-10 06:47:00,103 : INFO : 在第 188000 次循环的平均损失为: 22.089082
# 2024-10-10 06:47:06,703 : INFO : 在第 190000 次循环的平均损失为: 23.915225
# 2024-10-10 06:47:06,704 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:47:08,757 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 女儿, UNK, 家庭, 后, 一名, 生平, 一位, 中, 儿子,
# 2024-10-10 06:47:08,782 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 台湾, 年, 文化, 日本, 国家, 前, 香港, 历史, 主要,
# 2024-10-10 06:47:08,807 : INFO : 单词 电脑 的最相似的 10 个单词为： 使用, 领域, 包括, 设计, 相关, 技术, 专家, 称为, 游戏, 研究,
# 2024-10-10 06:47:08,831 : INFO : 单词 手机 的最相似的 10 个单词为： 服务, 核心, 通讯, 成为, 已, 推出, 运行, 软件, 特殊, 网络,
# 2024-10-10 06:47:08,856 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版, 年, 人物, 作品, 一部, 故事, 没有, 影片, 英文, 语言,
# 2024-10-10 06:47:08,881 : INFO : 单词 公里 的最相似的 10 个单词为： 约, 城市, 东西, 地区, 长度, 市区, 主要, 区域, 内, 位于,
# 2024-10-10 06:47:08,905 : INFO : 单词 还 的最相似的 10 个单词为： 包括, 中, 时, 都, 上, 做, 后来, 不, 没有, 年,
# 2024-10-10 06:47:08,929 : INFO : 单词 部分 的最相似的 10 个单词为： 包括, 上, 中, 主要, 大部分, 地区, 分别, 都, 区, 区域,
# 2024-10-10 06:47:08,953 : INFO : 单词 年 的最相似的 10 个单词为： 后, 前, 日, 月, 美国, 成为, 中, 时, 英国, 期间,
# 2024-10-10 06:47:08,977 : INFO : 单词 之后 的最相似的 10 个单词为： 年, 后, 中, 日, 后来, 离开, 时, 继续, 前, 最后,
# 2024-10-10 06:47:15,559 : INFO : 在第 192000 次循环的平均损失为: 22.322959
# 2024-10-10 06:47:22,232 : INFO : 在第 194000 次循环的平均损失为: 22.694349
# 2024-10-10 06:47:28,764 : INFO : 在第 196000 次循环的平均损失为: 21.938152
# 2024-10-10 06:47:35,502 : INFO : 在第 198000 次循环的平均损失为: 21.390842
# 2024-10-10 06:47:42,098 : INFO : 在第 200000 次循环的平均损失为: 22.919971
# 2024-10-10 06:47:42,099 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:47:44,165 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 家庭, 女儿, 结婚, 生于, 一位, 一名, 时, 人, 生平,
# 2024-10-10 06:47:44,193 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 历史, 文化, 美国, 成为, 日本, 政治, 台湾, 年, 发展,
# 2024-10-10 06:47:44,219 : INFO : 单词 电脑 的最相似的 10 个单词为： 设计, 游戏, 相关, 包括, 应用, 内容, 使用, 电子, 制造, 推出,
# 2024-10-10 06:47:44,245 : INFO : 单词 手机 的最相似的 10 个单词为： 核心, 上, 服务, 宣布, 精神, 现代, 内容, 南庵, 成为, 推出,
# 2024-10-10 06:47:44,271 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版, 出现, 生活, 作品, 作家, 人物, 时, 著作, 不少, 语言,
# 2024-10-10 06:47:44,297 : INFO : 单词 公里 的最相似的 10 个单词为： 约, 境内, 东西, 达, 位于, 南北, 长度, 城市, 面积, 市区,
# 2024-10-10 06:47:44,322 : INFO : 单词 还 的最相似的 10 个单词为： 上, 之后, 中, 不, 都, 称为, 后来, 亦, 外, 包括,
# 2024-10-10 06:47:44,349 : INFO : 单词 部分 的最相似的 10 个单词为： UNK, 要求, 称为, 不, 都, 中, 上, 下, 三个, 大部分,
# 2024-10-10 06:47:44,375 : INFO : 单词 年 的最相似的 10 个单词为： 后, 共, 中, 成为, 之后, 月, 期间, 人, 时, 日本,
# 2024-10-10 06:47:44,401 : INFO : 单词 之后 的最相似的 10 个单词为： 年, 时, 后, 还, 上, 后来, 中, 人, 成为, 继续,
# 2024-10-10 06:47:50,906 : INFO : 在第 202000 次循环的平均损失为: 20.466997
# 2024-10-10 06:47:57,488 : INFO : 在第 204000 次循环的平均损失为: 21.437147
# 2024-10-10 06:48:04,132 : INFO : 在第 206000 次循环的平均损失为: 19.526457
# 2024-10-10 06:48:10,756 : INFO : 在第 208000 次循环的平均损失为: 20.137568
# 2024-10-10 06:48:17,090 : INFO : 在第 210000 次循环的平均损失为: 19.018927
# 2024-10-10 06:48:17,092 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:48:19,137 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 曾, 出生, 家庭, 儿子, 后来, 结婚, 生于, 妻子, 时,
# 2024-10-10 06:48:19,165 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 历史, 年, 美国, 日本, 文化, 台湾, 上, 成为, 新,
# 2024-10-10 06:48:19,192 : INFO : 单词 电脑 的最相似的 10 个单词为： 设计, 电子, 计算机, 使用, 表示, 推出, 领域, 相关, 采用, 结构,
# 2024-10-10 06:48:19,217 : INFO : 单词 手机 的最相似的 10 个单词为： 特殊, 软件, 计算机, 现代, 还, 设计, 分析, 不同, 宣布, 通讯,
# 2024-10-10 06:48:19,242 : INFO : 单词 书籍 的最相似的 10 个单词为： 发行, 故事, 出现, 人物, 作品, 中国, 出版, 著作, 作家, 方面,
# 2024-10-10 06:48:19,266 : INFO : 单词 公里 的最相似的 10 个单词为： 东西, 之间, 境内, 约, 达, 长度, 河流, 条, 长, 全长,
# 2024-10-10 06:48:19,290 : INFO : 单词 还 的最相似的 10 个单词为： 中, 上, 不, 包括, 之后, 新, 当时, 后来, 年, 人,
# 2024-10-10 06:48:19,314 : INFO : 单词 部分 的最相似的 10 个单词为： 大部分, 包括, 中, 上, 分别, 不, 还, 内, 三个, 特殊,
# 2024-10-10 06:48:19,338 : INFO : 单词 年 的最相似的 10 个单词为： 月, 美国, 后, 之后, 成为, 中, 日, 获得, 后来, 前,
# 2024-10-10 06:48:19,363 : INFO : 单词 之后 的最相似的 10 个单词为： 年, 后, 时, 成为, 后来, 中, 还, 继续, 日, 日本,
# 2024-10-10 06:48:25,924 : INFO : 在第 212000 次循环的平均损失为: 18.289857
# 2024-10-10 06:48:32,667 : INFO : 在第 214000 次循环的平均损失为: 18.721513
# 2024-10-10 06:48:39,405 : INFO : 在第 216000 次循环的平均损失为: 19.429174
# 2024-10-10 06:48:46,091 : INFO : 在第 218000 次循环的平均损失为: 21.460339
# 2024-10-10 06:48:52,789 : INFO : 在第 220000 次循环的平均损失为: 18.921778
# 2024-10-10 06:48:52,791 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:48:54,816 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 生平, 后来, 结婚, 儿子, 女儿, 出生, 生于, 妻子, UNK,
# 2024-10-10 06:48:54,841 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 年, 历史, 日本, 上, 国家, 成为, 美国, 发展, 当时,
# 2024-10-10 06:48:54,865 : INFO : 单词 电脑 的最相似的 10 个单词为： 设计, 电子, 应用, 系统, 计算机, 使用, 技术, 一种, 采用, 类似,
# 2024-10-10 06:48:54,890 : INFO : 单词 手机 的最相似的 10 个单词为： 软件, 生产, 内容, 计算机, 日, 公司, 计划, 推出, 分析, 服务,
# 2024-10-10 06:48:54,914 : INFO : 单词 书籍 的最相似的 10 个单词为： 人物, 年, 相关, 中国, 发行, 故事, 出版社, 资料, 文章, 内容,
# 2024-10-10 06:48:54,938 : INFO : 单词 公里 的最相似的 10 个单词为： 速度, 长, 分钟, 东西, 线, 小时, 机场, 宽, 约, 达到,
# 2024-10-10 06:48:54,961 : INFO : 单词 还 的最相似的 10 个单词为： 中, 上, 包括, 都, UNK, 时, 不, 后来, 年, 后,
# 2024-10-10 06:48:54,985 : INFO : 单词 部分 的最相似的 10 个单词为： 上, 使用, 都, 主要, 中, 包括, 称为, 已经, 三个, 提供,
# 2024-10-10 06:48:55,010 : INFO : 单词 年 的最相似的 10 个单词为： 后, 成为, 月, 之后, 时, 期间, 日本, 同年, 前, 已,
# 2024-10-10 06:48:55,033 : INFO : 单词 之后 的最相似的 10 个单词为： 年, 时, 后, 成为, 中, 都, 前, 亦, 上, 当时,
# 2024-10-10 06:49:01,703 : INFO : 在第 222000 次循环的平均损失为: 18.525050
# 2024-10-10 06:49:08,161 : INFO : 在第 224000 次循环的平均损失为: 17.272058
# 2024-10-10 06:49:14,778 : INFO : 在第 226000 次循环的平均损失为: 19.040264
# 2024-10-10 06:49:21,369 : INFO : 在第 228000 次循环的平均损失为: 18.063687
# 2024-10-10 06:49:28,089 : INFO : 在第 230000 次循环的平均损失为: 18.486039
# 2024-10-10 06:49:28,091 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:49:30,125 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 女儿, 后来, 出生, 妻子, 生平, 结婚, 一名, UNK, 去世,
# 2024-10-10 06:49:30,151 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 年, 国家, 文化, 历史, 台湾, 中, 发展, 成为, 时期,
# 2024-10-10 06:49:30,175 : INFO : 单词 电脑 的最相似的 10 个单词为： 应用, 技术, 设计, 电子, 研究, 领域, 系统, 使用, 平台, 物理,
# 2024-10-10 06:49:30,200 : INFO : 单词 手机 的最相似的 10 个单词为： 分析, 公司, 成为, 使用, 软件, 得以, 日, 连续, 作, 能力,
# 2024-10-10 06:49:30,224 : INFO : 单词 书籍 的最相似的 10 个单词为： 中, 小说, 出版, 人物, 中国, 作品, 出版社, 作家, 文字, 年,
# 2024-10-10 06:49:30,248 : INFO : 单词 公里 的最相似的 10 个单词为： 长, 约, 宽, 东西, 全长, 最大, 达, 之间, 机场, 超过,
# 2024-10-10 06:49:30,271 : INFO : 单词 还 的最相似的 10 个单词为： 中, 不, 没有, 都, 人, 时, 后来, 使, 之后, 只,
# 2024-10-10 06:49:30,295 : INFO : 单词 部分 的最相似的 10 个单词为： 上, 中, 主要, 亦, 还, 后, 都, 三个, 只, 内,
# 2024-10-10 06:49:30,318 : INFO : 单词 年 的最相似的 10 个单词为： 后, 日, 之后, 美国, 月, 至今, 成为, 期间, 中, 成立,
# 2024-10-10 06:49:30,341 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 年, 时, 中, 月, 曾, 当时, 日, 成为, 后来,
# 2024-10-10 06:49:36,906 : INFO : 在第 232000 次循环的平均损失为: 18.613321
# 2024-10-10 06:49:43,299 : INFO : 在第 234000 次循环的平均损失为: 18.163797
# 2024-10-10 06:49:49,904 : INFO : 在第 236000 次循环的平均损失为: 17.644335
# 2024-10-10 06:49:56,455 : INFO : 在第 238000 次循环的平均损失为: 18.211222
# 2024-10-10 06:50:03,020 : INFO : 在第 240000 次循环的平均损失为: 16.925705
# 2024-10-10 06:50:03,022 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:50:05,050 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 出生, 一名, 儿子, 生平, 妻子, UNK, 去世, 生于, 逝世,
# 2024-10-10 06:50:05,075 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 文化, 日本, 国家, 美国, 年, 现代, 台湾, 欧洲, 发展,
# 2024-10-10 06:50:05,099 : INFO : 单词 电脑 的最相似的 10 个单词为： 技术, 电子, 计算机, 应用, 一种, 领域, 类似, 设计, 描述, 包括,
# 2024-10-10 06:50:05,123 : INFO : 单词 手机 的最相似的 10 个单词为： 推出, 模式, 能力, 公司, 计算机, 服务, 软件, 记录, 后来, 精神,
# 2024-10-10 06:50:05,149 : INFO : 单词 书籍 的最相似的 10 个单词为： 中国, 小说, 作者, 出版社, 人物, 方面, 美国, 出版, 作品, 作家,
# 2024-10-10 06:50:05,173 : INFO : 单词 公里 的最相似的 10 个单词为： 约, 宽, 长, 最大, 东西, 境内, 最高, 小时, 机场, 之间,
# 2024-10-10 06:50:05,197 : INFO : 单词 还 的最相似的 10 个单词为： 中, 很多, 都, 时, UNK, 上, 不, 没有, 可能, 之后,
# 2024-10-10 06:50:05,221 : INFO : 单词 部分 的最相似的 10 个单词为： 上, 中, UNK, 包括, 亦, 都, 加上, 外, 再, 均,
# 2024-10-10 06:50:05,245 : INFO : 单词 年 的最相似的 10 个单词为： 后, 日, 当时, 成为, 美国, 日本, 之后, 期间, 第一次, 逝世,
# 2024-10-10 06:50:05,270 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 时, 当时, 中, 年, 下, UNK, 人, 曾, 日,
# 2024-10-10 06:50:11,805 : INFO : 在第 242000 次循环的平均损失为: 17.061269
# 2024-10-10 06:50:18,384 : INFO : 在第 244000 次循环的平均损失为: 17.582660
# 2024-10-10 06:50:24,813 : INFO : 在第 246000 次循环的平均损失为: 16.429480
# 2024-10-10 06:50:31,095 : INFO : 在第 248000 次循环的平均损失为: 17.139687
# 2024-10-10 06:50:37,323 : INFO : 在第 250000 次循环的平均损失为: 16.802190
# 2024-10-10 06:50:37,324 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:50:39,372 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 出生, UNK, 后来, 儿子, 一名, 生平, 年轻, 生于, 出,
# 2024-10-10 06:50:39,399 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 年, 台湾, 国家, 文化, 日本, UNK, 美国, 中, 曾,
# 2024-10-10 06:50:39,427 : INFO : 单词 电脑 的最相似的 10 个单词为： 技术, 设备, 领域, 电子, 平台, 还, 包括, 研究, 相关, 使用,
# 2024-10-10 06:50:39,455 : INFO : 单词 手机 的最相似的 10 个单词为： 最终, 公司, 动画, 媒体, 推出, 计算机, 作品, 集, 获得, 得以,
# 2024-10-10 06:50:39,483 : INFO : 单词 书籍 的最相似的 10 个单词为： 内容, 作者, 文字, 台湾, 发表, 中国, 杂志, 中, 包括, 新,
# 2024-10-10 06:50:39,510 : INFO : 单词 公里 的最相似的 10 个单词为： 约, 长, 小时, 处, 宽, 达, 全长, 境内, 铁路, 更,
# 2024-10-10 06:50:39,536 : INFO : 单词 还 的最相似的 10 个单词为： 上, 都, 中, 后, 当时, 时, 不, UNK, 没有, 包括,
# 2024-10-10 06:50:39,562 : INFO : 单词 部分 的最相似的 10 个单词为： 上, 都, 中, 时, 包括, 未, 主要, 大, 三个, 更,
# 2024-10-10 06:50:39,588 : INFO : 单词 年 的最相似的 10 个单词为： 后, 日, 曾, 美国, 成为, 时, 前, 日本, 英国, 新,
# 2024-10-10 06:50:39,614 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 中, 时, 曾, 当时, 日, 年, UNK, 最后, 不久,
# 2024-10-10 06:50:46,056 : INFO : 在第 252000 次循环的平均损失为: 16.805294
# 2024-10-10 06:50:52,495 : INFO : 在第 254000 次循环的平均损失为: 16.175473
# 2024-10-10 06:50:59,076 : INFO : 在第 256000 次循环的平均损失为: 15.580078
# 2024-10-10 06:51:05,677 : INFO : 在第 258000 次循环的平均损失为: 17.901316
# 2024-10-10 06:51:12,278 : INFO : 在第 260000 次循环的平均损失为: 16.495613
# 2024-10-10 06:51:12,279 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:51:14,311 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 去世, 生平, 王, UNK, 出生, 逝世, 死, 继承, 妻子,
# 2024-10-10 06:51:14,337 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 年, 国家, 台湾, 美国, 著名, 日本, 主要, 年代, 中,
# 2024-10-10 06:51:14,361 : INFO : 单词 电脑 的最相似的 10 个单词为： 技术, 电子, 设备, 包含, 特别, 系统, 使用, 一种, 装置, 中,
# 2024-10-10 06:51:14,386 : INFO : 单词 手机 的最相似的 10 个单词为： 必须, 获得, 出, 使用, UNK, 宣布, 系统, 电影, 需, 技术,
# 2024-10-10 06:51:14,411 : INFO : 单词 书籍 的最相似的 10 个单词为： 作者, 中, 文章, 内容, 新, 重要, 主要, 发表, 文化, 中国,
# 2024-10-10 06:51:14,436 : INFO : 单词 公里 的最相似的 10 个单词为： 达, 全长, 小时, 约, 建成, 长, 境内, 达到, 路线, 处,
# 2024-10-10 06:51:14,460 : INFO : 单词 还 的最相似的 10 个单词为： 中, 上, 时, UNK, 没有, 不, 很, 包括, 出, 当时,
# 2024-10-10 06:51:14,484 : INFO : 单词 部分 的最相似的 10 个单词为： 中, 主要, 内, 大, 上, 包括, 分为, 方面, 组成, 没有,
# 2024-10-10 06:51:14,508 : INFO : 单词 年 的最相似的 10 个单词为： 后, 日, 前, 月, 时, 成为, 之后, 期间, 曾, 获得,
# 2024-10-10 06:51:14,531 : INFO : 单词 之后 的最相似的 10 个单词为： 年, 后, 时, 人, 大, 前, 中, 最后, 月, 曾,
# 2024-10-10 06:51:21,111 : INFO : 在第 262000 次循环的平均损失为: 15.766164
# 2024-10-10 06:51:27,594 : INFO : 在第 264000 次循环的平均损失为: 16.170471
# 2024-10-10 06:51:34,388 : INFO : 在第 266000 次循环的平均损失为: 16.427434
# 2024-10-10 06:51:40,959 : INFO : 在第 268000 次循环的平均损失为: 16.382803
# 2024-10-10 06:51:47,540 : INFO : 在第 270000 次循环的平均损失为: 16.211949
# 2024-10-10 06:51:47,541 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:51:49,579 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 生平, 一名, 出生, 说, 人, 逝世, UNK, 曾, 早年,
# 2024-10-10 06:51:49,604 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 日本, 台湾, 文化, 年, 亦, 中, 包括, 世界, 著名,
# 2024-10-10 06:51:49,627 : INFO : 单词 电脑 的最相似的 10 个单词为： 设备, 技术, 简称, 系统, 应用, 能够, 中, 机械, 公司, 游戏,
# 2024-10-10 06:51:49,651 : INFO : 单词 手机 的最相似的 10 个单词为： 平台, 数位, 计算机, 公司, 电脑, 使用, 技术, 推出, 获得, 电影,
# 2024-10-10 06:51:49,674 : INFO : 单词 书籍 的最相似的 10 个单词为： 作者, 中, 报纸, 内容, 文章, 中国, 古代, 指出, 之前, 杂志,
# 2024-10-10 06:51:49,698 : INFO : 单词 公里 的最相似的 10 个单词为： 超过, 长, 约, 全长, 达, 距, 南北, 东西, 宽, 处,
# 2024-10-10 06:51:49,722 : INFO : 单词 还 的最相似的 10 个单词为： 都, 没有, 中, UNK, 不, 时, 后, 却, 人, 外,
# 2024-10-10 06:51:49,746 : INFO : 单词 部分 的最相似的 10 个单词为： 包括, 都, 大, 上, 大部分, 小, 主要, 分为, 没有, 下,
# 2024-10-10 06:51:49,769 : INFO : 单词 年 的最相似的 10 个单词为： 月, 日, 后, 成为, 时, 获得, 中, 日本, 前, 美国,
# 2024-10-10 06:51:49,793 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 年, 成为, 最后, 时, 中, 不久, 曾, 亦, 后来,
# 2024-10-10 06:51:56,393 : INFO : 在第 272000 次循环的平均损失为: 14.354281
# 2024-10-10 06:52:02,945 : INFO : 在第 274000 次循环的平均损失为: 16.305737
# 2024-10-10 06:52:09,505 : INFO : 在第 276000 次循环的平均损失为: 16.063863
# 2024-10-10 06:52:15,997 : INFO : 在第 278000 次循环的平均损失为: 16.499502
# 2024-10-10 06:52:22,568 : INFO : 在第 280000 次循环的平均损失为: 14.541971
# 2024-10-10 06:52:22,569 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 06:52:24,604 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 人, 逝世, 生平, 儿子, 说, 早年, 孩子, 出生, 生于,
# 2024-10-10 06:52:24,631 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 日本, 年, 亦, 台湾, 文化, 人, 美国, 历史, 国家,
# 2024-10-10 06:52:24,655 : INFO : 单词 电脑 的最相似的 10 个单词为： 技术, 领域, 计算机, 设备, 中, 系统, 简称, 科学, 电影, 研究,
# 2024-10-10 06:52:24,679 : INFO : 单词 手机 的最相似的 10 个单词为： 数位, 平台, 推出, 电脑, 公司, 计算机, 出, 计划, 游戏, 技术,
# ...
# 2024-10-10 07:27:31,218 : INFO : 单词 部分 的最相似的 10 个单词为： 中, 上, 称为, 部份, 都, 包括, 三个, 均, 无, 主要,
# 2024-10-10 07:27:31,241 : INFO : 单词 年 的最相似的 10 个单词为： 之后, 后, 之前, 曾, 月, 中, 期间, 曾于, 当时, 历史,
# 2024-10-10 07:27:31,264 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 年, 之前, 才, 时, 当时, 后来, 已经, 直到, 最后,
# 2024-10-10 07:27:37,924 : INFO : 在第 882000 次循环的平均损失为: 7.718637
# 2024-10-10 07:27:44,462 : INFO : 在第 884000 次循环的平均损失为: 6.960816
# 2024-10-10 07:27:51,056 : INFO : 在第 886000 次循环的平均损失为: 7.248709
# 2024-10-10 07:27:57,486 : INFO : 在第 888000 次循环的平均损失为: 7.211066
# 2024-10-10 07:28:04,218 : INFO : 在第 890000 次循环的平均损失为: 6.882660
# 2024-10-10 07:28:04,219 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 07:28:06,264 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 父母, 出生, 家中, UNK, 弟弟, 夫人, 妻子, 儿子, 后来,
# 2024-10-10 07:28:06,290 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 年, 国际, 上海, 北京, 日本, 台湾, 海外, 香港, 韩国,
# 2024-10-10 07:28:06,314 : INFO : 单词 电脑 的最相似的 10 个单词为： 科学, 游戏, 应用, 电子, 资讯, 手机, 语言, 技术, 领域, 数位,
# 2024-10-10 07:28:06,338 : INFO : 单词 手机 的最相似的 10 个单词为： 游戏, 系列, 推出, 电脑, 个人, 电影, 网路, 版本, 网络, 动画,
# 2024-10-10 07:28:06,362 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版, 著作, 出版社, 一本, 作品, 书, 发表, 作者, 文艺, 小说,
# 2024-10-10 07:28:06,385 : INFO : 单词 公里 的最相似的 10 个单词为： 距离, 全长, 英里, 速度, 长度, 处, 距, 约, 小时, 最大,
# 2024-10-10 07:28:06,408 : INFO : 单词 还 的最相似的 10 个单词为： 没有, 上, 中, 已经, 不, 曾, 时, 包括, 之后, 这是,
# 2024-10-10 07:28:06,433 : INFO : 单词 部分 的最相似的 10 个单词为： 都, 主要, 包括, 上, 均, 使用, 现在, 全部, 中, 不,
# 2024-10-10 07:28:06,457 : INFO : 单词 年 的最相似的 10 个单词为： 后, 之后, 曾, 月, 之前, 日, 正式, 同年, 期间, 曾于,
# 2024-10-10 07:28:06,480 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 时, 才, 年, 已经, 曾, 后来, 之前, 最后, 再次,
# 2024-10-10 07:28:12,976 : INFO : 在第 892000 次循环的平均损失为: 6.988823
# 2024-10-10 07:28:19,532 : INFO : 在第 894000 次循环的平均损失为: 7.102866
# 2024-10-10 07:28:26,096 : INFO : 在第 896000 次循环的平均损失为: 7.389719
# 2024-10-10 07:28:32,560 : INFO : 在第 898000 次循环的平均损失为: 6.972674
# 2024-10-10 07:28:39,069 : INFO : 在第 900000 次循环的平均损失为: 6.503421
# 2024-10-10 07:28:39,070 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 07:28:41,138 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 父母, 出生, 早年, 生平, 家中, 一名, 儿子, 结婚, 妻子,
# 2024-10-10 07:28:41,163 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 台湾, 曾, 国际, 香港, 北京, 年, 当时, 历史, 文化,
# 2024-10-10 07:28:41,187 : INFO : 单词 电脑 的最相似的 10 个单词为： 游戏, 应用, 功能, 技术, 资讯, 科学, 领域, 手机, 电子, 系列,
# 2024-10-10 07:28:41,211 : INFO : 单词 手机 的最相似的 10 个单词为： 游戏, 电脑, 系列, 推出, 网路, 提供, 公司, 动画, 网络, 下载,
# 2024-10-10 07:28:41,234 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版, 出版社, 作品, 著作, 书, 一本, 小说, 作者, 写, 编辑,
# 2024-10-10 07:28:41,257 : INFO : 单词 公里 的最相似的 10 个单词为： 距离, 英里, 全长, 约, 公尺, 距, 小时, 速度, 位于, 处,
# 2024-10-10 07:28:41,280 : INFO : 单词 还 的最相似的 10 个单词为： 没有, 曾, 时, 后来, 中, 不, 这是, 亦, 之后, 仍,
# 2024-10-10 07:28:41,303 : INFO : 单词 部分 的最相似的 10 个单词为： 包括, 上, 都, 中, 仅, 主要, 部份, 下, 大部分, 现在,
# 2024-10-10 07:28:41,327 : INFO : 单词 年 的最相似的 10 个单词为： 后, 曾, 月, 同年, 期间, 中, 已, 正式, 成为, 曾于,
# 2024-10-10 07:28:41,350 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 时, 最后, 才, 后来, 年, 再次, 没有, 直到, 便,
# 2024-10-10 07:28:47,747 : INFO : 在第 902000 次循环的平均损失为: 6.552172
# 2024-10-10 07:28:54,440 : INFO : 在第 904000 次循环的平均损失为: 6.453478
# 2024-10-10 07:29:01,104 : INFO : 在第 906000 次循环的平均损失为: 6.634635
# 2024-10-10 07:29:07,760 : INFO : 在第 908000 次循环的平均损失为: 7.153330
# 2024-10-10 07:29:14,333 : INFO : 在第 910000 次循环的平均损失为: 7.007537
# 2024-10-10 07:29:14,334 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 07:29:16,452 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 儿子, 父母, 出生, 结婚, 妻子, 后来, 家中, 家人, 女儿,
# 2024-10-10 07:29:16,479 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 台湾, 曾, 国际, 年, 国家, 先后, 历史, 著名, 香港,
# 2024-10-10 07:29:16,505 : INFO : 单词 电脑 的最相似的 10 个单词为： 应用, 资讯, 电子, 使用, 转换, 技术, 功能, 透过, 同步, 操作,
# 2024-10-10 07:29:16,532 : INFO : 单词 手机 的最相似的 10 个单词为： 电脑, 系列, 游戏, 网路, 公司, 提供, 推出, 网络, 全新, 版本,
# 2024-10-10 07:29:16,558 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版, 作品, 著作, 出版社, 一本, 写, 撰写, 作者, 书, 阅读,
# 2024-10-10 07:29:16,584 : INFO : 单词 公里 的最相似的 10 个单词为： 全长, 距离, 英里, 约, 小时, 公尺, 面积, 达到, 达, 需,
# 2024-10-10 07:29:16,611 : INFO : 单词 还 的最相似的 10 个单词为： 后来, 中, 没有, 亦, 曾, 不, 时, 上, 当时, 已经,
# 2024-10-10 07:29:16,638 : INFO : 单词 部分 的最相似的 10 个单词为： 地区, 包括, 亦, 现在, 中, 内, 已, 大部分, 主要, 外,
# 2024-10-10 07:29:16,665 : INFO : 单词 年 的最相似的 10 个单词为： 曾, 后, 年底, 正式, 已, 同年, 之后, 中, 成为, 以来,
# 2024-10-10 07:29:16,690 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 才, 时, 中, 再, 最后, 之前, 后来, 已, 年,
# 2024-10-10 07:29:23,186 : INFO : 在第 912000 次循环的平均损失为: 7.322235
# 2024-10-10 07:29:29,835 : INFO : 在第 914000 次循环的平均损失为: 7.164177
# 2024-10-10 07:29:36,294 : INFO : 在第 916000 次循环的平均损失为: 7.347358
# 2024-10-10 07:29:42,922 : INFO : 在第 918000 次循环的平均损失为: 6.926337
# 2024-10-10 07:29:49,512 : INFO : 在第 920000 次循环的平均损失为: 6.809240
# 2024-10-10 07:29:49,514 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 07:29:51,570 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 出生, 儿子, 妻子, 父母, 弟弟, 女儿, 家中, 后来, 家人,
# 2024-10-10 07:29:51,596 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 年, 国家, 国际, 主要, 成立, 台湾, 香港, 国内, 英国,
# 2024-10-10 07:29:51,621 : INFO : 单词 电脑 的最相似的 10 个单词为： 模式, 应用, 使用, 转换, 操作, 发布, 资讯, 使用者, 手机, 产品,
# 2024-10-10 07:29:51,648 : INFO : 单词 手机 的最相似的 10 个单词为： 系列, 游戏, 电脑, 网路, 全新, 版本, 推出, 购买, 公司, 平台,
# 2024-10-10 07:29:51,674 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版, 著作, 出版社, 作品, 书, 一本, 撰写, 小说, 评论, 作者,
# 2024-10-10 07:29:51,701 : INFO : 单词 公里 的最相似的 10 个单词为： 全长, 距离, 约, 公尺, 小时, 英里, 距, 速度, 面积, 长度,
# 2024-10-10 07:29:51,727 : INFO : 单词 还 的最相似的 10 个单词为： 上, 之后, 当时, 后来, 不, 更, 已经, 亦, 没有, 中,
# 2024-10-10 07:29:51,751 : INFO : 单词 部分 的最相似的 10 个单词为： 地区, 包括, 主要, 部份, 大部分, 国家, 几个, 内, 现在, 包含,
# 2024-10-10 07:29:51,777 : INFO : 单词 年 的最相似的 10 个单词为： 后, 曾, 之后, 获得, 前, 后来, 中, 成为, 日, 期间,
# 2024-10-10 07:29:51,803 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 年, 后来, 之前, 还, 成为, 已, 便, 结束, 才,
# 2024-10-10 07:29:58,581 : INFO : 在第 922000 次循环的平均损失为: 6.651468
# 2024-10-10 07:30:05,286 : INFO : 在第 924000 次循环的平均损失为: 7.060936
# 2024-10-10 07:30:11,877 : INFO : 在第 926000 次循环的平均损失为: 7.392882
# 2024-10-10 07:30:18,481 : INFO : 在第 928000 次循环的平均损失为: 6.923584
# 2024-10-10 07:30:25,118 : INFO : 在第 930000 次循环的平均损失为: 7.033190
# 2024-10-10 07:30:25,119 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 07:30:27,161 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 出生, 儿子, 父母, 妻子, 后来, 女儿, 哥哥, 家中, 死,
# 2024-10-10 07:30:27,187 : INFO : 单词 中国 的最相似的 10 个单词为： 年, 大陆, 历史, 国内, 法国, 国家, 美国, 日本, 国际, 东亚,
# 2024-10-10 07:30:27,212 : INFO : 单词 电脑 的最相似的 10 个单词为： 应用, 使用, 手机, 技术, 转换, 透过, 系统, 产品, 提供, 计算机,
# 2024-10-10 07:30:27,239 : INFO : 单词 手机 的最相似的 10 个单词为： 电脑, 开发, 系列, 网路, 支持, 透过, 使用者, 提供, 购买, 微软,
# 2024-10-10 07:30:27,264 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版, 出版社, 著作, 书, 一本, 小说, 撰写, 作品, 作者, 编辑,
# 2024-10-10 07:30:27,288 : INFO : 单词 公里 的最相似的 10 个单词为： 距离, 全长, 约, 处, 长度, 英里, 距, 公尺, 面积, 速度,
# 2024-10-10 07:30:27,312 : INFO : 单词 还 的最相似的 10 个单词为： 上, 没有, 之后, 不, 已经, 亦, 无法, 都, 现在, 后,
# 2024-10-10 07:30:27,335 : INFO : 单词 部分 的最相似的 10 个单词为： 区, 里, 调整, 班次, 使用, 车站, 仅, 部份, 中, 改为,
# 2024-10-10 07:30:27,359 : INFO : 单词 年 的最相似的 10 个单词为： 后, 月, 之后, 曾, 期间, 获得, 时期, 成为, 以来, 结束,
# 2024-10-10 07:30:27,384 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 后来, 年, 还, 上, 直到, 曾, 才, 此后, 便,
# 2024-10-10 07:30:33,919 : INFO : 在第 932000 次循环的平均损失为: 6.536466
# 2024-10-10 07:30:40,351 : INFO : 在第 934000 次循环的平均损失为: 6.667732
# 2024-10-10 07:30:46,993 : INFO : 在第 936000 次循环的平均损失为: 6.637397
# 2024-10-10 07:30:53,532 : INFO : 在第 938000 次循环的平均损失为: 6.439683
# 2024-10-10 07:31:00,194 : INFO : 在第 940000 次循环的平均损失为: 6.479169
# 2024-10-10 07:31:00,195 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 07:31:02,275 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 出生, 儿子, 妻子, 后来, 祖父, 父母, 弟弟, 女儿, 逝世,
# 2024-10-10 07:31:02,301 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 年, 日本, 国际, 香港, 北京, 上海, 国内, 历史, 韩国,
# 2024-10-10 07:31:02,326 : INFO : 单词 电脑 的最相似的 10 个单词为： 技术, 计算机, 应用, 手机, 系统, 透过, 领域, 系列, 科学, 提供,
# 2024-10-10 07:31:02,351 : INFO : 单词 手机 的最相似的 10 个单词为： 电脑, 开发, 游戏, 透过, 网路, 系列, 提供, 支援, 使用者, 推出,
# 2024-10-10 07:31:02,375 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版, 出版社, 著作, 书, 作品, 编辑, 一本, 小说, 阅读, 撰写,
# 2024-10-10 07:31:02,400 : INFO : 单词 公里 的最相似的 10 个单词为： 全长, 距离, 英里, 约, 距, 到达, 处, 道, 位于, 小时,
# 2024-10-10 07:31:02,425 : INFO : 单词 还 的最相似的 10 个单词为： 没有, 时, 上, 不, 都, 直接, 之后, 现在, 便, 已经,
# 2024-10-10 07:31:02,453 : INFO : 单词 部分 的最相似的 10 个单词为： 部份, 使用, 主要, 国家, 中, 包含, 仅, 地区, 森林, 内,
# 2024-10-10 07:31:02,480 : INFO : 单词 年 的最相似的 10 个单词为： 后, 月, 成为, 曾, 获得, 期间, 以来, 直到, 已, 正式,
# 2024-10-10 07:31:02,507 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 后来, 时, 便, 成为, 才, 再次, 没有, 年, 还,
# 2024-10-10 07:31:09,151 : INFO : 在第 942000 次循环的平均损失为: 6.655662
# 2024-10-10 07:31:15,682 : INFO : 在第 944000 次循环的平均损失为: 6.645345
# 2024-10-10 07:31:22,336 : INFO : 在第 946000 次循环的平均损失为: 7.178432
# 2024-10-10 07:31:28,969 : INFO : 在第 948000 次循环的平均损失为: 6.886626
# 2024-10-10 07:31:35,552 : INFO : 在第 950000 次循环的平均损失为: 7.022159
# 2024-10-10 07:31:35,554 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 07:31:37,613 : INFO : 单词 父亲 的最相似的 10 个单词为： 出生, 母亲, 祖父, 儿子, 后来, 父母, 妻子, 逝世, 弟弟, 一位,
# 2024-10-10 07:31:37,639 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 国际, 年, 历史, 现代, 上海, 日本, 香港, 协会, 先后,
# 2024-10-10 07:31:37,664 : INFO : 单词 电脑 的最相似的 10 个单词为： 科学, 技术, 领域, 透过, 计算机, 系统, 设备, 开发, 学, 应用,
# 2024-10-10 07:31:37,690 : INFO : 单词 手机 的最相似的 10 个单词为： 开发, 网路, 透过, 电脑, 推出, 使用者, 功能, 游戏, 显示, 数位,
# 2024-10-10 07:31:37,714 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版, 著作, 出版社, 书, 编辑, 作品, 文化, 一本, 小说, 撰写,
# 2024-10-10 07:31:37,740 : INFO : 单词 公里 的最相似的 10 个单词为： 全长, 距离, 英里, 距, 公尺, 约, 千米, 达到, 大约, 速度,
# 2024-10-10 07:31:37,765 : INFO : 单词 还 的最相似的 10 个单词为： 时, 不, 没有, 都, 后, 上, 却, 后来, 便, 之后,
# 2024-10-10 07:31:37,790 : INFO : 单词 部分 的最相似的 10 个单词为： 部份, 使用, 国家, 上, 包括, 仅, 森林, 中, 主要, 地区,
# 2024-10-10 07:31:37,816 : INFO : 单词 年 的最相似的 10 个单词为： 后, 月, 期间, 日, 曾于, 曾, 正式, 直到, 同年, 历史,
# 2024-10-10 07:31:37,843 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 时, 后来, 成为, 才, 下, 便, 当时, 上, 还,
# 2024-10-10 07:31:44,438 : INFO : 在第 952000 次循环的平均损失为: 7.233952
# 2024-10-10 07:31:50,985 : INFO : 在第 954000 次循环的平均损失为: 7.340535
# 2024-10-10 07:31:57,488 : INFO : 在第 956000 次循环的平均损失为: 7.688817
# 2024-10-10 07:32:03,980 : INFO : 在第 958000 次循环的平均损失为: 6.639063
# 2024-10-10 07:32:10,528 : INFO : 在第 960000 次循环的平均损失为: 6.872856
# 2024-10-10 07:32:10,529 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 07:32:12,625 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 出生, 儿子, 妻子, 父母, 弟弟, 逝世, 其父, 后来, 祖父,
# 2024-10-10 07:32:12,651 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 年, 北京, 称, 曾, 上海, 日本, 国际, 历史, 现代,
# 2024-10-10 07:32:12,675 : INFO : 单词 电脑 的最相似的 10 个单词为： 技术, 计算机, 透过, 科学, 设备, 开发, 系统, 使用, 游戏, 应用,
# 2024-10-10 07:32:12,700 : INFO : 单词 手机 的最相似的 10 个单词为： 电脑, 推出, 开发, 网路, 使用者, 利用, 透过, 游戏, 支援, 使用,
# 2024-10-10 07:32:12,724 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版社, 出版, 书, 著作, 一本, 小说, 作品, 编辑, 原名, 阅读,
# 2024-10-10 07:32:12,748 : INFO : 单词 公里 的最相似的 10 个单词为： 距, 英里, 距离, 全长, 小时, 站, 穿过, 千米, 机场, 到达,
# 2024-10-10 07:32:12,772 : INFO : 单词 还 的最相似的 10 个单词为： 不, 时, 没有, 上, 都, 现在, 更, 中, 只, 直接,
# 2024-10-10 07:32:12,796 : INFO : 单词 部分 的最相似的 10 个单词为： 中, 包括, 使用, 部份, 上, 内, 都, 包含, 没有, 分为,
# 2024-10-10 07:32:12,820 : INFO : 单词 年 的最相似的 10 个单词为： 期间, 后, 月, 曾, 正式, 当时, 之后, 成为, 日, 前,
# 2024-10-10 07:32:12,844 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 成为, 时, 后来, 当时, 年, 才, 亦, 下, 最后,
# 2024-10-10 07:32:19,509 : INFO : 在第 962000 次循环的平均损失为: 7.092229
# 2024-10-10 07:32:26,268 : INFO : 在第 964000 次循环的平均损失为: 6.708404
# 2024-10-10 07:32:32,966 : INFO : 在第 966000 次循环的平均损失为: 7.021064
# 2024-10-10 07:32:39,559 : INFO : 在第 968000 次循环的平均损失为: 6.958500
# 2024-10-10 07:32:45,988 : INFO : 在第 970000 次循环的平均损失为: 6.805952
# 2024-10-10 07:32:45,989 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 07:32:48,095 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 出生, 丈夫, 儿子, 弟弟, 父母, 早年, 女儿, 过世, 去世,
# 2024-10-10 07:32:48,122 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 年, 台湾, 现代, 日本, 国际, 曾, 历史, 北京, 著名,
# 2024-10-10 07:32:48,148 : INFO : 单词 电脑 的最相似的 10 个单词为： 技术, 透过, 系统, 一种, 游戏, 开发, 使用, 电子, 领域, 设备,
# 2024-10-10 07:32:48,174 : INFO : 单词 手机 的最相似的 10 个单词为： 电脑, 游戏, 使用者, 推出, 利用, 开发, 网路, 支援, 电视, 使用,
# 2024-10-10 07:32:48,199 : INFO : 单词 书籍 的最相似的 10 个单词为： 著作, 出版, 书, 出版社, 小说, 阅读, 文化, 现代, 原名, 中国,
# 2024-10-10 07:32:48,225 : INFO : 单词 公里 的最相似的 10 个单词为： 距离, 小时, 英里, 距, 约, 全长, 位于, 千米, 达到, 速度,
# 2024-10-10 07:32:48,251 : INFO : 单词 还 的最相似的 10 个单词为： 没有, 时, 上, 当时, 不, 后, 更, 做, 仍, 现在,
# 2024-10-10 07:32:48,276 : INFO : 单词 部分 的最相似的 10 个单词为： 部份, 国家, 主要, 森林, 使用, 中, 年, 地区, 内, 现今,
# 2024-10-10 07:32:48,300 : INFO : 单词 年 的最相似的 10 个单词为： 后, 月, 期间, 直到, 成为, 美国, 正式, 曾于, 同年, 曾,
# 2024-10-10 07:32:48,325 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 时, 才, 最后, 后来, 便, 当时, 再, 仍, 成为,
# 2024-10-10 07:32:54,874 : INFO : 在第 972000 次循环的平均损失为: 6.796895
# 2024-10-10 07:33:01,464 : INFO : 在第 974000 次循环的平均损失为: 6.515017
# 2024-10-10 07:33:08,072 : INFO : 在第 976000 次循环的平均损失为: 6.699711
# 2024-10-10 07:33:14,547 : INFO : 在第 978000 次循环的平均损失为: 6.567421
# 2024-10-10 07:33:21,038 : INFO : 在第 980000 次循环的平均损失为: 6.526958
# 2024-10-10 07:33:21,040 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 07:33:23,104 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 出生, 父母, 儿子, 曾, 弟弟, 一位, 女儿, 两人, 妻子,
# 2024-10-10 07:33:23,132 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 台湾, 年, 日本, 香港, 上海, 曾, 简称, 国际, 历史,
# 2024-10-10 07:33:23,157 : INFO : 单词 电脑 的最相似的 10 个单词为： 设备, 开发, 透过, 技术, 系统, 提供, 用于, 电子, 功能, 游戏,
# 2024-10-10 07:33:23,181 : INFO : 单词 手机 的最相似的 10 个单词为： 电脑, 游戏, 推出, 提供, 版本, 开发, 使用, 网路, 针对, 利用,
# 2024-10-10 07:33:23,205 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版社, 出版, 著作, 书, 小说, 作者, 内容, 一本, 原名, 中,
# 2024-10-10 07:33:23,231 : INFO : 单词 公里 的最相似的 10 个单词为： 距离, 小时, 全长, 距, 约, 千米, 英里, 长度, 达, 大约,
# 2024-10-10 07:33:23,255 : INFO : 单词 还 的最相似的 10 个单词为： 不, 没有, 时, 更, 当时, 上, 中, 都, 曾, 之后,
# 2024-10-10 07:33:23,280 : INFO : 单词 部分 的最相似的 10 个单词为： 中, 包括, 使用, 主要, 上, 大部分, 类似, 内, 部份, 仍,
# 2024-10-10 07:33:23,304 : INFO : 单词 年 的最相似的 10 个单词为： 后, 正式, 月, 同年, 之后, 成为, 期间, 年间, 已, 曾,
# 2024-10-10 07:33:23,329 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 时, 才, 当时, 成为, 最后, 便, 年, 直到, 中,
# 2024-10-10 07:33:30,029 : INFO : 在第 982000 次循环的平均损失为: 6.684044
# 2024-10-10 07:33:36,638 : INFO : 在第 984000 次循环的平均损失为: 6.712645
# 2024-10-10 07:33:43,273 : INFO : 在第 986000 次循环的平均损失为: 6.959403
# 2024-10-10 07:33:49,868 : INFO : 在第 988000 次循环的平均损失为: 6.681476
# 2024-10-10 07:33:56,582 : INFO : 在第 990000 次循环的平均损失为: 7.071566
# 2024-10-10 07:33:56,584 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 07:33:58,649 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 出生, 儿子, 父母, 女儿, 弟弟, UNK, 妻子, 家中, 生于,
# 2024-10-10 07:33:58,675 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 年, 历史, 国家, 日本, 英国, 曾, 中, 当时, 主要,
# 2024-10-10 07:33:58,700 : INFO : 单词 电脑 的最相似的 10 个单词为： 系统, 技术, 提供, 开发, 电子, 通讯, 游戏, 设备, 系列, 领域,
# 2024-10-10 07:33:58,725 : INFO : 单词 手机 的最相似的 10 个单词为： 电脑, 提供, 游戏, 产品, 使用, 购买, 亦, 系列, 技术, 微软,
# 2024-10-10 07:33:58,750 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版社, 著作, 出版, 书, 小说, 内容, 故事, 原名, 一本, 书名,
# 2024-10-10 07:33:58,775 : INFO : 单词 公里 的最相似的 10 个单词为： 距离, 距, 约, 小时, 全长, 英里, 达, 千米, 大约, 位于,
# 2024-10-10 07:33:58,799 : INFO : 单词 还 的最相似的 10 个单词为： 时, 没有, 不, 上, 更, 都, 亦, 仍, 中, 当时,
# 2024-10-10 07:33:58,823 : INFO : 单词 部分 的最相似的 10 个单词为： 中, 上, 亦, 包括, 均, 现在, 内, 时, 都, 主要,
# 2024-10-10 07:33:58,848 : INFO : 单词 年 的最相似的 10 个单词为： 后, 之后, 正式, 同年, 期间, 成为, 中, 月, 曾, 日,
# 2024-10-10 07:33:58,872 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 年, 时, 成为, 中, 当时, 才, 仍, 后来, 再,
# 2024-10-10 07:34:05,589 : INFO : 在第 992000 次循环的平均损失为: 7.054777
# 2024-10-10 07:34:12,164 : INFO : 在第 994000 次循环的平均损失为: 7.010971
# 2024-10-10 07:34:18,891 : INFO : 在第 996000 次循环的平均损失为: 6.686777
# 2024-10-10 07:34:25,395 : INFO : 在第 998000 次循环的平均损失为: 6.548888
# 2024-10-10 07:34:31,988 : INFO : 在第 1000000 次循环的平均损失为: 6.745328
# 2024-10-10 07:34:31,989 : INFO : 验证单词与最相似的 10 个单词：
# 2024-10-10 07:34:34,039 : INFO : 单词 父亲 的最相似的 10 个单词为： 母亲, 出生, 弟弟, 女儿, 父母, 早年, 家中, 妻子, 哥哥, 丈夫,
# 2024-10-10 07:34:34,065 : INFO : 单词 中国 的最相似的 10 个单词为： 大陆, 年, 台湾, 历史, 日本, 上海, 美国, 国家, 香港, 曾,
# 2024-10-10 07:34:34,090 : INFO : 单词 电脑 的最相似的 10 个单词为： 系统, 使用, 游戏, 技术, 数位, 提供, 设备, 开发, 电子, 功能,
# 2024-10-10 07:34:34,114 : INFO : 单词 手机 的最相似的 10 个单词为： 电脑, 游戏, 使用, 媒体, 亦, 产品, 上, 电话, 购买, 系列,
# 2024-10-10 07:34:34,137 : INFO : 单词 书籍 的最相似的 10 个单词为： 出版社, 出版, 著作, 小说, 书, 作者, 写作, 描述, 文字, 一本,
# 2024-10-10 07:34:34,161 : INFO : 单词 公里 的最相似的 10 个单词为： 约, 距离, 位于, 距, 小时, 达, 附近, 千米, 全长, 英里,
# 2024-10-10 07:34:34,185 : INFO : 单词 还 的最相似的 10 个单词为： 时, 都, 没有, 更, 不, 上, 中, 亦, 得到, 之后,
# 2024-10-10 07:34:34,210 : INFO : 单词 部分 的最相似的 10 个单词为： 上, 主要, 均, 亦, 使用, 大部分, 两个, 不同, 中, 时,
# 2024-10-10 07:34:34,234 : INFO : 单词 年 的最相似的 10 个单词为： 月, 后, 同年, 正式, 成为, 曾, 之后, 后来, 已, 加入,
# 2024-10-10 07:34:34,257 : INFO : 单词 之后 的最相似的 10 个单词为： 后, 时, 后来, 上, 年, 最后, 才, 中, 还, 再,
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
